# %% [markdown]
# In this section we will use RNN for a very simple task, which is character level language model. This is a many to many example of RNN.
#
# **WorkFLow**:
#   - feed a sequence of characters into RNN
#   - at every time step we will ask the RNN to predict the next word.
#
# Let's say, we have a training sequence of just one string "hello" and we have a vocabulary $V \in \{\text{"h"}, \text{"e"}, \text{"l"}, \text{"o"}\}$

# %% [markdown]
# ### Work procedure:
#  we know the basic of RNN and its equation from the previous section. Now we will make one hot vector for each corresponding letter in the vocabulary as follows.
#
# ![alt text](images/5.PNG)
#
# Then we will feed into RNN a single vecton at once at a single time step. Initially the $h_0$ is an empty vector of size 3 in this case. Now applying the RNN function with the same weight matrix we get as follows,
#
# $\begin{aligned}
# \begin{bmatrix}0.3 \\ -0.1 \\ 0.9 \end{bmatrix} &= f_W(W_{hh}\begin{bmatrix}0 \\ 0 \\ 0 \end{bmatrix} + W_{xh}\begin{bmatrix}1 \\ 0 \\ 0 \\ 0 \end{bmatrix}) \ \ \ \ &(1) \\
# \begin{bmatrix}1.0 \\ 0.3 \\ 0.1 \end{bmatrix} &= f_W(W_{hh}\begin{bmatrix}0.3 \\ -0.1 \\ 0.9 \end{bmatrix} + W_{xh}\begin{bmatrix}0 \\ 1 \\ 0 \\ 0 \end{bmatrix}) \ \ \ \ &(2) \\
# \begin{bmatrix}0.1 \\ -0.5 \\ -0.3 \end{bmatrix} &= f_W(W_{hh}\begin{bmatrix}1.0 \\ 0.3 \\ 0.1 \end{bmatrix} + W_{xh}\begin{bmatrix}0 \\ 0 \\ 1 \\ 0 \end{bmatrix}) \ \ \ \ &(3) \\
# \begin{bmatrix}-0.3 \\ 0.9 \\ 0.7 \end{bmatrix} &= f_W(W_{hh}\begin{bmatrix}0.1 \\ -0.5 \\ -0.3 \end{bmatrix} + W_{xh}\begin{bmatrix}0 \\ 0 \\ 1 \\ 0 \end{bmatrix}) \ \ \ \ &(4)
# \end{aligned}$
#
# ![alt text](images/cg6.PNG)

# %% [markdown]
# **Embedding layer**: It is a layer that converts categorical data, words or characters into dense vectors of real numbers. This process of representing categorical datat as continuous vectors is known as embedding. To convert a one hot vector into embedding layer we need to take an embedding matrix and then perfrom matrix multiplication between this matrix and the one hot vector.

# %% [markdown]
# We can also predict the next character at each timestep. Since there are 4 characters in the vocabulary, predicted vector at each time step is 4 dimensional.
#
# ![alt text](images/6.PNG)
#
# At first we fed "h" in the network. RNN predicts next charcter at this time step with current settings of weights as,
# $\begin{bmatrix}1.0 \\ 2.2 \\ -3.0 \\ 4.1 \end{bmatrix} \rightarrow \begin{bmatrix}\text{"h"} \\ \text{"e"} \\ \text{"l"}\\ \text{"o"} \end{bmatrix}$

# %% [markdown]
# Here, the scores refers to the corresponding characters in the vocabulary. For example 1.0 for "h" and so on. But the prediction of each time step will be the character corresponding to the highest score. In this case highest score value is 4.1 which refers to "0". That means at this time step we don't get our predicted "e" which refers to wrong prediction and high loss as well.

# %% [markdown]
# At test time, we will feed one character(prefix) to the RNN and get a sample for that time step. We will put this sample to the next time step. We use sample for the next time step is actually a benifit becuase by doing so the the model can diversify.
#
# **Q** Why do we use one hot as input instead of softmax vector at test time?
#
# **Ans**: Because the model is trained with one hot vector. Therefore if it sees other than this then it may fail to give correct output. Moreover, in practical the input may be too large. For example, if we generater word instead of character then the vocabulary contains any word in english dictionary. This is computationally really bad.
#
# ![alt text](images/7.PNG)

# %% [markdown]
# ### Backpropagation and Gradient calculation
# In this process of RNN forward propagation is kind of forward through time and backward propagation is backward through time. Therefore if the example is too large such as one whole wikipedia article then for all the words in forward pass and then calculating gradients for all the words and updating the gradient is not practical. Because it will take long in fact model will not converge. Therfore we will calculate loss only after a certain number of steps say 100 and so on. By doing so the forward pass and all the hidden time step remains the same but the backward pass and gradient calculations become easier because we only calculate gradients over the stepped loss. we call this method **Truncated Backpropagation** through time.
#
# ![alt text](images/9.PNG) ![alt text](images/8.PNG)

# %% [markdown]
# ### Gradient flow for vanilla RNN
#
# We already know, RNN takes previous hidden state $h_{t-1}$ and input $x_t$ at any time step t, and pass the calculated result through tanh, $h_t = tanh(W_{hh}h_{t-1} + W_{xh}x_t)$.
# For backpropagation we need to find out how the last time step affects the weights of the first time step $W_{hh}$
#
# **calculating gradients**:
# The partial derivative of $h_t$ w.r.t. $h_{t-1}$ is, $\frac{\partial h_t}{\partial h_{t-1}} =  tanh^{'}(W_{hh}h_{t-1} + W_{xh}x_t)W_{hh}$
#
# We update $W_{hh}$ by getting derivative of loss at last time step w.r.t. $W_{hh}$.
#
# $\begin{aligned}
# \frac{\partial L_{t}}{\partial W_{hh}} = \frac{\partial L_{t}}{\partial h_{t}} \frac{\partial h_{t}}{\partial h_{t-1} } \dots \frac{\partial h_{1}}{\partial W_{hh}} \\
# = \frac{\partial L_{t}}{\partial h_{t}}(\prod_{t=2}^{T} \frac{\partial h_{t}}{\partial  h_{t-1}})\frac{\partial h_{1}}{\partial W_{hh}} \\
# = \frac{\partial L_{t}}{\partial h_{t}}(\prod_{t=2}^{T}  tanh^{'}(W_{hh}h_{t-1} + W_{xh}x_t)W_{hh}^{T-1})\frac{\partial h_{1}}{\partial W_{hh}} \\
# \end{aligned}$

# %% [markdown]
# Now it's time to apply all these theory into code. Here I will use the code which was written by **Karpathy** and will analyse the code.
#
# Code link: https://gist.github.com/karpathy/d4dee566867f8291f086

# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
# Out:
# '\nMinimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)\nBSD License\n'

# %%
import numpy as np
# data I/O
data = open('data/Venus_and_Adonis.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print ('data has %d characters, %d unique.' % (data_size, vocab_size))
# Out:
# data has 1136 characters, 43 unique.

# %%
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# %% [markdown]
# These dictionaries are created to map characters to their corresponding integer indices and vice versa. These dictionaries are useful when particulary working with text datas.

# %%
# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# %%
# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %% [markdown]
# - this function generates a sequence of integers from a trained RNN language model. It takes an initial memory state "h", a seed character index "seed_ix" to start generation, and the desired sequence length "n".
# - x is used to represent the one hot encodeing of the current character
# - ixes: to store generated character indices.
# - ix = np.random.choice(range(vocab_size), p=p.ravel()): Sample the next character index (ix) from the probability distribution p. This is done using np.random.choice, which selects an index from range(vocab_size) with the probabilities defined by p.
# - x[ix] = 1: Set the element in x at index ix to 1, encoding the character that was selected as the next character in the sequence.

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

# %%
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter 
  if n==500000:
    break
# Out:
# ----
#  ad toâ€kre withen,
#
#  And yreind nasith pand thye hove toy lold-fiugwith sealive thys t steith that hee a
#
# Heir aind sekdisunty:
#  Move thaf and hourâ€™ss;
#
# â€™d see c.ost seingyn  hithek,
#
# HHe-chat r
# ----
# iter 5400, loss: 34.792482
# ----
#   sich pr
#  And pan
#
#
#
# â€™urtyâfe, wided the wisn then and don shid  d
#
#
#
#
# Anndece then too hindd belnand se tyy
#
# Mome pang nis thouv
#
#  Veusufeedyme, ton he thot lim,d wot himis tho wemedâ€™d d
# ----
# iter 5500, loss: 34.356470
# ----
#  e;â€˜€˜€˜bucses sute wim hus  haseesw;
#
# â€˜Thed dthen wit shte sham refâ€™d boufawe the baber, florhâ€™d on shen,  on Sfpir thith chet: Ao kink-bog;
#
#  Mons thufâ€™d dlin
#
# Siprir.
#
# Bure a loir cosun,
#
# ----
# iter 5600, loss: 34.033631
# ----
#   d
#
# S-€™dde-Anonn logh,
# â€™dlyie, o bogi ,
#  bipsher;
#
# â€˜wished longhet roth scorer parst stelfre fiela
#  bathâ€™d;e womre love le;
#
#  bier thistpy thasithy mafâ€™ldy wisued woo thos Vaothas dacan sake
# ----
# iter 5700, loss: 33.622358
# ----
#   a
#  bucisto ao sVelyy,
#
#  €˜Andlp-nt ssetari to thlu logred
#
# M liisne;
#
#
# Hurit shee lous lvath mamere doner thor an hithend he lovâ€f than sore,,  a lo thh frog an the amig thor fâ€™s syman nato sa
# ----
# iter 5800, loss: 33.225868
# ----
#  shein wod hogind with sulphiseâ€™ rien,
#
#  €˜n-heewâ€™e lak, meig oneun wet ree,
#
# Addâ€™d, bouk-cert seathae tons mmamith câo˜
#
# Apnngâ€™d,
# d re the kimm at styend sut het seat rboun,
#
#  R€™t;
#
#  â€™d s t
# ----
# iter 5900, loss: 32.852610
# ----
#  wirire wiste,
#
#
# Bet,
#
#  Sthie the sato fact;
#
#  And linss:
# Aun ty
#
#  Tisn with tisin list  fâ€™d sblgved sece a
#
#
#  to€™d ts;
#  Saiken reu roru  nokint no limy thith tabt mikt hapailg notrâ€™d dind hin
# ----
# iter 6000, loss: 32.531477
# ----
#   levâ€™s teath,
#  I™dec-
# Bucâ€™deiwhur thit,
#
# â€˜And lice tce wilf clyshen abt ile-tVasew,
#
# â€˜gune that seithes teathe what.
#  aVtoved he fapir tre thaureld he,
#
#  Aut dâ€™r raetyy, c t
#  Saakinl het
# ----
# iter 6100, loss: 32.259848
# ----
#  ics câ€™d thit ho ,
#
#
# Veirosree suliunghe wimlons,
#  bilis lik lognt,
#
# â€˜An ton snem. thy to€d ro thy theeuradin conenweut his than seavorl,  m sht seadenlyy;
#
# â€˜Th thansusth fapishe mignd,
#
# Iâ€˜Thu
# ----
# iter 6200, loss: 31.944614
# ----
#  ad timing to whe fith faev love, with,
#
# Making wen
#  o to tongnu the that stee withovfâ€™ tce widic swechrâ€™s ssed saddâ€™d Vatheer,
#
#
# A;n tongur thasueldengâ€™draun,
#
# :T: beddymafed wissed,
#
#  A
# ----
# iter 6300, loss: 31.555233
# ----
#  t hs thafe keend ™ol het o kid staml aidingyn,
#
# â€™ss sashe-IAned
#
# Tdeceâ€™s s thachiet mucâ€™d sucâ€™d se the mougremer,
#
#  Mod theed hid thus sire, ad they re thongulpine wits,
#
#
# Addeide tond thint
# ----
# iter 6400, loss: 31.307815
# ----
#  edeu tompun hye ton his sisdecwhsetyâ€˜bec;
#
#  If bed,;
#
#  And buelyy, closer, this tirein hiell,
#
#  bind his thits chith, doun hed and houn wit romir,
#   a
#  bel, mome-lov;;
#
#
# Ad nedtyed hon rors;
#
# â€˜Tin
# ----
# iter 6500, loss: 31.018266
# ----
#  â€˜Thit lh:
# Hove-An hur, f pne man with sem, mther fovein ho gsed in lig then,â€™e to thou wno thet and houseut theu kilg. thet aboungharn with wamothan lov lwâ€™d ty ter tond hotinm thace andaiit mh
# ----
# iter 6600, loss: 30.686669
# ----
#   sove;
#
# A thaveen wet, a™d dad the wit shis lfasei lorse fimis tan severeen shithâ€™s dand he thet feifee-begg:
#
# Heir rausrecâ€™d dore thlerat sherse syamirt rmeprer feikoth sal,
#
#  Asbumores, af cle
# ----
# iter 6700, loss: 30.411333
# ----
#  -buur, m thos fee maug
#
#
#  :
#
# Mose s omee his lore,  wisseng;
#
#
# Ten his dat
#
# â€™sreen an lonun t
#
# Buk-feey wit loud,
# â€sun yokis rons srort,
#
#  And  adin,
#
#  Mortre thor Volin he bouhhe witon hod ho
# ----
# iter 6800, loss: 30.191017
# ----
#  thoughist snant c™nld lat dove lov;
#
# â˜And oloun tond leun
#
# â˜Thek, firs râ€™id rimisst cheikh withyâ€™s saedyoughâ€™ speng worispan, moas thamea amy fimis thou wemt micm, ming â€™d,
#
#  wilt liclt love
# ----
# iter 6900, loss: 29.943163
# ----
#  e lorer an,
#
# â€˜The lore borepy wissuth câlyhe, hy love:
#
# Mfephre lorle hatl iet one hant cSile,
#
#
# â€˜Thin,
#
# â€˜The tod le thae wot hy thy Ifort;
#
# â€˜The  lo t hle an love.
#
# Hec™s, boar coâ€™syed hee
# ----
# iter 7000, loss: 29.643338
# ----
#  aved,
#
# HeVfy :
#
# Byer to whed,
#
# â€˜Thir the k-ce alir styeveruf lod spe bat anou oSt cher th emath hpang he thee wetwes thame wilfy sthed,
#
#  But tadoign womm.
#
#  And a
#
#
#  And thare to weega;
#
# And:
#
#
#  th
# ----
# iter 7100, loss: 29.352331
# ----
#  ad treed he load nove an uinid hin, thoukaply aailld ame loves thse logre thot notu Iid and set,
#
# Ard,
#
#
# T;n he fipl fored to
#
# A thein ho that sed he thed lons,â€˜gunthy lavey,
# Hirs familgi; fit, t
# ----
# iter 7200, loss: 29.046974
# ----
#   re-bakeid weteâ€™s amiuthy seilisse donis sye,
#
#
#  oithe woand see hont sted,  hin ro  h theid sen kided nimre, lo doved wispret sed nem ah tpasusseef wilicer doved hin tom cod thort try thouswâ€™
# ----
# iter 7300, loss: 28.826338
# ----
#  ee kicr tha;
#
# â€˜gAd tane chegâthy,;
#
#  ™iun wes thâ€™dlevâ€™s bied his thiem her thâ€™e ad there,
#
#  Scare a
#
# Bist, s hiss fafelfwech be-fouthy:â€™.  o Hacur oiel love,y la˜ve.A tt â€c he ay thons;
#
# HH
# ----
# iter 7400, loss: 28.601679
# ----
#   indeun sher, fall meeg witt ssemin hipl,,
#  Sard,,e sier cherel, Naicd suressararif the shee:
#
#  Siril, as dowen wilt, fathred ar themishev thee log per,
#
# â€˜The aping wedpill, anlyu buseo wildose;
#
# SR
# ----
# iter 7500, loss: 28.291798
# ----
#  daddongne his lirt râ€™s rmoph thith shes fovâ€™d ag goth thandanganin hinthae lokghâ€™dler movâ€™d lign
#
#  And her
#
# â€˜Thuste seddlegâ€™d And,
#
#  And hau womy love.
#  him cho f thos wâ€™t abuth mane pas
# ----
# iter 7600, loss: 27.987403
# ----
#  -beave sacis,  m
#
#  Sirto, mand thas seed,
#
#
# Ten aNd ty abinld lont
#
# Hethet:
#
#
#
# Add thed he thees,
#
# Beiken abour to sin, his thas ane one-begwed oongnun nonur tfe lopr thors, yfepren sss fame thos
# ----
# iter 7700, loss: 27.712620
# ----
#  dopnd yserd, witf thred ylt sechern hin hy to him.
#
#  bore long  t ri
#
#
#  Sredt;
#
#
# Heurano hil he lovd hed a™d bet, yto s rit ho whevâ€™ clo ,
#
#  chilt rith thas cmasse and the the thr be, lohss;
#
#  And
# ----
# iter 7800, loss: 27.392040
# ----
#  s râ€™ild ret and huilor seed the horne doloug sore. rapHor corgh threr amd cori blghethymed, buth thee wee love bouthyy to wholer, thol ant fefâ€™d se tove;
#
#  Silg thent ase bing as that mat thith fe
# ----
# iter 7900, loss: 27.162691
# ----
#  eng wiling omee foth serâ€™ thas fâ€™ld nongred sous to hthâ€™s hre done, wisle wod reethy sele-nauthâ€™s chhmet, mpies marer tore boughe, âIâ€™d pithe socghâ€™dher phet and,
#  tond se wit this plogs t
# ----
# iter 8000, loss: 26.971895
# ----
#  ad taâ€™en aan none with tret sham and he thes roping wist madour noud
#
# Add oddd Vâ€™ls ree wilh the wid hon ynt he paonghed lac
#
#   and wn bust whitrâ€™er che wamove, wiendy ymakisnekreef pas thormroâ
# ----
# iter 8100, loss: 26.792291
# ----
#  y af kid cond nasted kille kermors thore nikt re wisiepang movur hihs to wimor lors,
#  If thakis t I
#  Maddein huan ore tim ind bnt;
#
# â€˜Thet a™ tymed muret, m o the fakint man nanit dovo;e add thot hun
# ----
# iter 8200, loss: 26.527619
# ----
#  ove, werirt swetfy: pir thy râ€™er chen wat rhe saty;
# A she chorm as ased, math satheen wis this  har tiss wisn,  thy to he;
#
#  Naei-bauswem pang at     w thunty;
# â€˜Thet maen ho thilis this sapilhy to
# ----
# iter 8300, loss: 26.267877
# ----
#
#
# â€™, thy kee wilf thaun tom chen loleVoashe he ghot ytossef othuf meus,
#  Bill amakhe dint makes sov,
#
#  And hire a g lor she-
# â€™l a
#
#  I™daVdand,
#
# Heekely werou-fain lov,
#
# â€˜The rait seochei thas
# ----
# iter 8400, loss: 26.074315
# ----
#  d and enongnd seisithen and hon,
#
#
# Ask;
#
#  If dipl.  hil, ther log thyes se with shee witheph dond  hit lagnt recu faling hithrâ€she can ane whet mautar S abumleghe thye lomi lovâ€™d, an lon heeth suse
# ----
# iter 8500, loss: 25.869026
# ----
#  ;
#
#  And a
# Huut yse thee wit roninb aman none logs thisses ton fore wien he thisself,
#
# â€™d adond histe Ait shar us snoukâ€™d, but re the suato his shist;
#
# Beren his pliset fotty to silp: ame his sVocs
# ----
# iter 8600, loss: 25.668566
# ----
#  buse what seeangu w€eve;
#
# MBer,
#
#  c˜Vâ€™d seusâ€™s satang miore kisses fwathis shee, weth wethore loverle, one noue-chorâ. h do mong-belThe wiety;
#
#
# As maun logne, thin,
#
#  Natue tomad he bus sfesus mm
# ----
# iter 8700, loss: 25.440429
# ----
#   stâ€™le gating her, f wilt sneghet chise;
#
#  Sta™ this plvmâ€™d dilu
#
#
#
# â€™d, abir safainn seed,
#
#
#  And re thaken core thake nous thint mwissefa;
#
# , Stase; woth t an an the that stois re, thirer,
# ----
# iter 8800, loss: 25.197354
# ----
#  ifelfâ€™s c hef this th thove abogsâ€™sl, ait hith sadeind wed long hedâ€˜gwint snt sot suithes:
#
#
#
# â€˜And yet huibe,
#   or
#  â€˜g-dpint makerte womad re thadenbe-farpang wetpassss:â€™dd an love-fachre
# ----
# iter 8900, loss: 24.896453
# ----
#  ad taâ€˜Vwepses sheuk
#
#
#
# And weetyy;
#
#
#  buker hse,
#
#  thes anor chere,
#  Marin to bipe â€™d ponsse;
#
#  Ifâ€™ thy bufed,   om thoen,
#
# Bust sivermy to s bogr thas lor mfeer thas aligng hed,
#
#  But fathe
# ----
# iter 9000, loss: 24.574533
# ----
#   hith,
#
#
# A chit, Mo Saddongne logun than hee wimir the weouid,  lil whet feithed  yolirhe sepd;oatheek nthes secthe and thed Votim done his thamorid hos wisld secgsed wendor˜Vlonure farit ssere loagn
# ----
# iter 9100, loss: 24.434517
# ----
#  e saddipar clor,
#
#  Naturee, wo thouth,
#
#  Morec he ton h kelo asen hophs;
#
# â€˜Thire.  o kieliym.  mAml, mpaus al,
#
#  Seiclre, mors saitt a
#
#
# Minly wete laei o.
#
#
# A Sacd
#
# A site chpair pit,
#   hogn
# ----
# iter 9200, loss: 24.303853
# ----
#  Here with thor ree kit styst;
#
# TededHun a
#  R  lipig to tond lou;
#
#  Bus rofeir,
#  And sete
#
#  But rato sat
#
# I™ss; mane, and hed,
#  Saa™d thy the lover,
#
#  Mpith ™ored ywte ftaR
#
# Heire o byue coss th the
# ----
# iter 9300, loss: 24.105452
# ----
#  sied nonsund wensecerwâ€™d eratheke weng hat o tond lo hset souirs thist remithesAs thod llegte tymterer oath mate whore cashed,
#
#
# Tire whre wetweth marlely,, wim ong nogne ylole. man gnon namit he be
# ----
# iter 9400, loss: 24.091481
# ----
#  n see aon cisrerâ€™is  wig t ymlin, moth saed y
#  the that steid do or
#
#
# Beiret setyend ham at onour to homv, ma€™ liss fermelf erorâ€™d sendy;
# â€˜chothy:
#
#  And
# â€™es ong;
#
# Tet dat mpren thint dond s
# ----
# iter 9500, loss: 24.040052
# ----
#  sym thie,
#
# A that madecâ€™d cr to thee.
#
#  Nuted abeil chelpyy thor;
#
# And,
#
# A thed n
#
#
# Adeuto thore,,
#
#
#
#
# SThe mpanf tasim,
#
#
# âfâhâ€™dle-voakely welfare awill huigni hie,
#
# A the know: th thekereed;
#
#
# ----
# iter 9600, loss: 23.853934
# ----
#   lovâ€™d Anud houn wit hple thim,
#
# A nin tymeice tone kith thas cmong.
#
#  Sirdenedeunhy s ting tove a ling thous utog store wimse daus and in   h siddeen,
#
#  Nadith thour to woth thase; o th sasee whith
# ----
# iter 9700, loss: 23.635198
# ----
#  oveâ€™-snang an huety:â€™ddAny the  hou to sild-chat, o nore wedis thee woth sadddove-chous wein, w
#
#
# Heer, the that maeed hone,
#
#  And aAdenissesses ald hothâ€™d pad one lhu time, wiss ceapas sheit
# ----
# iter 9800, loss: 23.504176
# ----
#  ad addind,
#
#  Butin ay bus athâ€™d,
#
#
# Ann nouin wom he dint maker moven ro t :
#
# Hisst sato the kaddcest: thenf, seanisne and, nind hat thorâ€™t soning wed,
#
# Besh:â€™dd aSor snove-chess;
# â€™is tand seen
# ----
# iter 9900, loss: 23.291902
# ----
#   shith Imore,;
#
#  But tymabiling  hisn aro aro Sild, t c
#
#  Stin thong she,
#
#
# ITseddeigst;
#
#  And likld hamield estmer,
#
#  Asd uimine whed fatid colak thal, make will mins seilired hans tor tint dadll
# ----
# iter 10000, loss: 23.104682
# ----
#  ove,ymIf aldece;
#
#
#
# Te coud honle vored hor rorn hou beghet, thit surean shee wene whed  a bipllf,e chem,
#
#  buth;
#
#
#
# Andaint thas rath timore lous to wooy tor sebegustpang hed dony thre ritl honty
#
#
#
# ----
# iter 10100, loss: 22.875960
# ----
#  Heurâ€™is flo kith hanliil he migntyed sosr e ant seire wissec:
#
#
#  And Vestee wont mvechise lygne;
#
#
# Ten aboverhe;
#
#
#
# Adece wimer,
#
#  Ro˜˜Vocghre with faorg to aVoy the sheen tyhtâ€™d to hiss sarte,
#
#
# ----
# iter 10200, loss: 22.573863
# ----
#   a
#    o til hni, thne and sith fleoh ther fophre dond lo thorâ€™d sniling meoth seathes mreth thanenveabu;
#
#  More withess;
#
#  ™iciliple wher to wosser faek
#
#  Buts,
#
#  Natuty,
#
#  Voukhth set, far thyt Ant
# ----
# iter 10300, loss: 22.325634
# ----
#  s o hhe a
#
#
#  SVohun  o ling mort and,
#   hee lyh;
#
#
# â€™en well,
#
# Addd nonire thee don slebt he-thave,
#
#
# Aundwe yheit, monre lonth s lferâr™ thit sham boure done wim o milprne a
#
#  Sire wamaun lortâ€ver
# ----
# iter 10400, loss: 22.156009
# ----
#  whelf thouguseind hed And mâ€™dsrem,
#
#
# âR˜Tht thaiserm,
#  R
# â€˜An the tole wasping wethiâ€™dhere
#
#  Ryeteng meun  his llong wisld hor,
#  thied hilr that madt aIimit r mat mat tfafee want tod him rore;
#
#
# ----
# iter 10500, loss: 22.008828
# ----
#  sek-fwish thake, wee,  an tonld ht esae the with scâ€™d ce lacgâ€™d y thou wililc ht stenedâ€˜A wim ht seike a
#
#
#  Mor cor shor thâ€™d ho thave, thove chalilo: man wase chingâ€™dlong as the saed
# ----
# iter 10600, loss: 21.843898
# ----
#  ifâ€f feity horm, lovâ€™d he love, on loves hsasteve;
#
# Ane and piss csert this rhor,  f
#
#  tlo kaps t€e, wetto wrel and his ri™d trote nurot hithe horer plen nouf tect;
#  An tonsh tan ty thae fake wimlo
# ----
# iter 10700, loss: 21.902499
# ----
#  ad ustac™e dong see,
#
# A snilir loves wist  hime thas this lorâ€™ lous to wome boghâ€™d dore;
#
# Best;
#
#
# Be-câ€™d s ustore and, n n
#
#
# Tin dong tor,
#  din withevelf,e: w
#
# M€™e rnun ham deim seed liet,
#
#  f
# ----
# iter 10800, loss: 21.696547
# ----
#  re womiere him the whe thou Vote wimoun ho thou mone wine lovely al,y see, monus felire t
#
#  Stisureen alin.
#
#
#  And lithe and no, clon,
#
#  wint nworeis shan and ne loverh secrer,
#
#  Mre wited nan maker c
# ----
# iter 10900, loss: 21.478035
# ----
#  ore aro theis  honh an to thos mare winl ve, aman whe tyâ€™;
#
#  Morn ime wanty,â€˜The amug thas ceat ymer, wiss chafe,
#
#  IAndthee, thume tas tuath fophtâ€™s to thoug mius thof, to aligng;
#
#  Nadint nwat
# ----
# iter 11000, loss: 21.324955
# ----
#  Har the but mafeld he that sedere lov;
# â€™in to
#
#  More thee with kaloughppreth as dâ€™d thake.  monhis,  â€™d hith saseing ninth,
#    oHad dlove,
#
#  Sire nonl, wosldefâ€˜Thee loug therâ€™s pliser
# ----
# iter 11100, loss: 21.367803
# ----
#  sasny:
#
#  And t€fâ€™d hy thet seisit,
# â€˜˜wherâ€™s snanu t
#
#  Siddeneuve Ie ling aml hom hen ay thee with;
#
# A snady,
#  Iâ€™d,
#
# Hesh: m
#
#  Mic mone, wimir chplr setreth sheâ€™, tre with rto sind lirhe wat
# ----
# iter 11200, loss: 21.308946
# ----
#  s faveriht thore,
#
#  And ait tlaad poui loy keite nausumlfee, and, n core and yngno the thore, wore luin the move hio the the seod non louve done o one lorem,
#
#  Rosiut hser,
#
#
#
# Bethae bous seema
# â€˜Th
# ----
# iter 11300, loss: 21.147762
# ----
#  whandere thor with lafephrâ€™d, thit, more arHeld-vovâ€™d his thal and seddove wleve nakortr,e tov,
#  Saing to aligs tlfeen  his rore a bouus thy reding maf reit;
#
#  And ale-voakurer,
# ovein,  wisted da
# ----
# iter 11400, loss: 20.973747
# ----
#   th mam,
#
# H silt snunower, fiel hee,
#
# Aubith hsseinth mard liker chinl sermousll,â€™ thus, mass that ;â
# Huu sosis, Iâ€™gset shachesssel; movec hendeddesuu bo, him,
#
#
#
#  Sakkesndeing withes wol
# ----
# iter 11500, loss: 20.740333
# ----
#  ive.  nonen wore wowe,Ben, :
#
# TSthin,
#
#  Natucâ€™s f, ssere,
#
#  Hut ;
#
#  Hut at an ceipl fallf vmemato alogme thy thee don hse orore here this lafâ€™dlyrâ€f secgtâ€™sse saches :
# ye kid rofp,âfe-fogheer,
#
# ----
# iter 11600, loss: 20.555277
# ----
#  ad ati wocet sâ€shed y
#
#
# Hethet addongu this tar tint thicthrâ€™s lons keakinlingy,
#
#  Hanse;
#
#  Ifathâ€™d and ond fedâ€™d seirre, wit, thuimip.
#
#   an the s asutoak-chee love,
# o ilin hee with rame,
# ----
# iter 11700, loss: 20.358128
# ----
#  . thoth maeny lMore  hith that makrety;
#
# Ten:
#
# Makind th teve-ched love   a
#  ou V a
#  o to,  wissesw;
#
# Iâ€™lren haken wimad clo hy,
#
#  And ping see,
#
#  Ise m ane whit sbouk-chave,
#
#
# Beikthere,
#
#  Ant â€™
# ----
# iter 11800, loss: 20.185283
# ----
#  â€™d surertes saker,;
#  Ardedoner thein hon hempyet kedteghe sainin thin, mrou bege wisse womien hieslevâ€™d Adeichee with mame.   w tond
#
# â€˜Theu tond hon fither ind shor, them,
#
#  SBis;
#
#
#
#
# Ad hinty;
#
# ----
# iter 11900, loss: 20.000369
# ----
#  Here doun s the fawen,
#
#  Sice wit, wmâ€™d to sacguspano whte tay lon mabore ciss;
#
#  Nothusted ished wetty thise core live,
#
#
#
# â€ignt, f:an seddlf there ceelpy;
#
#
#
# An tyy tyand cos llol hemy he-
# ----
# iter 12000, loss: 19.826885
# ----
#   hiu thou;
#
#  Natint shathen wiliy,
#
#  ˜Verten ing no thet stosss;
#
#  More tich thistâfeare thin lor to€™d, thogw-thin heu noperâ€™ sean louh ther farer, moces ty,
#  m burte lacg
# â€™s, mwet shorerto align
# ----
# iter 12100, loss: 19.722249
# ----
#  -bere weth twethi tond r
#
#
#  R
# Be-ghoukelo heistedtere chin,
#
#  anun lor iligst maikins faer ley steed sheity hene a
#
#
#  Srien none,,
#
#  Stat tove-buote, a to thet mate that thein, mopk-thaus the-bu
# ----
# iter 12200, loss: 19.700100
# ----
#  sofadey,â€™- AddHe,
#
#  And to the ping ree love love,â€  hon.
#
#
# Bithekd hen sed to sace cemrees thoverhâ€™d to hild pan,
#
#  theve,e arer,
#
#  I˜voun nout thin,
#
# Asun,r thed to wit mann  hog tom ho she
# ----
# iter 12300, loss: 19.520435
# ----
#   phonkend wett seikisse him.
#
#  Sird dove whet thisss, fout noa™t nan liplpy thonty, fonle chple whougherderurthe thy t
#
#  bithed hon nowe wid, hy to mous to world. man love-fach;
#
#  And pere whet re lin
# ----
# iter 12400, loss: 19.341701
# ----
#  feen mor tog, mipsend yg this fle-baur lor,
#
#  Mor ceillrem walt mouk-core, falir, thiler,
#  If the whous seta
#
# Makisere ty:
#
# Austumaile.â€™dd tympere,
# â€˜The wity thore, wom rhes to thanely thist ra
# ----
# iter 12500, loss: 19.324206
# ----
#  ar
#
# â€˜Vhous;
#
# :
#
# And suithorn,
#
#  Hedengubee and snddeint maker tam cete aig one wit, set ra
#  tor todd feirie dong tos phon sever, mrithein he-beghe lave panu knghe thes lors fed,
#
# â€˜Thd saoke.h
# ----
# iter 12600, loss: 19.111296
# ----
#  . o a liy
# o r dour
#
# Iâ€™ll-facâ€™d hin s
#
#  And
# Adeing wet o kisus rot h thouit,
#
# Moke-beinind he loverre, y,
#      a
#  R
#
#  Hut mauind nn live withe;
#
# â€˜The ai
#  MHouk-than wint seigut asiedd
# ----
# iter 12700, loss: 18.983267
# ----
#  eveint hish lies,
#  Mor ceing as tyâ€˜There fith kâ€™ dong-n atl seteangustedeemy,â€™ lo-
#
# Makihle with saseing nthelf mae-caver anty to whe womir shis, Iâ€™d th scorith sasean hisse che whouâ€s s
# ----
# iter 12800, loss: 18.958728
# ----
#   Hut and lore wilsi, hith kathendaf snousdâ€™d se thasurpent mathyâfâ€™d ho tond wath thy stedeing an love-falk;
#
#  And leu: bour, fain thegwâ€s;
#
#  Bus fath mama
#
#
# â€˜Vhasuree thou wilt thu whou wang l
# ----
# iter 12900, loss: 18.805811
# ----
#   aoMunle whet hpas tov rte sils shem ton dore thee lowe  hain lovely alis ston hyt ating loun lor,
#
# A snut mothe;
#
# Tend bnu â€˜ghee,
#
#  Rastu wemae nour lo widte thous werpans reou™r tand doves dosem h
# ----
# iter 13000, loss: 18.632704
# ----
#  sty shes fwathe;
#
#  Staenmyp:
#
# oTe an pinu   o thet ,
#
#
# â€˜Vouchlesabored hy ti€™d,  o t and, nonung ymorphet movkernâpisselpyhan ty thet nove wils cht, m ononi
#
#  Mon lore wiss feve,
#
# Beif a dovo
# ----
# iter 13100, loss: 18.469631
# ----
#  wised wenty a  wit hs tereif, f sushee an wen hisnre an, tond houdand hore;
#
#  And amaun, wissevyusteand ynt mye him lim, fain ny,  hon log-twempant stossss:beikoun heed,
#
#
# â€˜Vang me-binh shekr thiuig
# ----
# iter 13200, loss: 18.440655
# ----
#   tro the than seegâ€™l, mym;
#
# â€˜Vang thustered y thos rhor,
#
# Mafiker tho hwassses;
#
# â€˜The pacle wemirl rome-faver, a™ ceth thet mmint on thauste manin wo tod thove, a™ cme colve cried feth to al
# ----
# iter 13300, loss: 18.264899
# ----
#  ean hithâ€™d falirn seem wainis reie that maisse and suth tamMoun wislr, at mote a bire chee,
#
#  kVegustedad saker, m
#
#  Mor cit reit hmore hein hish lrat ceimlas thas knoAs to wislre kecos;
#
# And Ane t
# ----
# iter 13400, loss: 18.104838
# ----
#  ad andâpe tond sert chourymo€™d, maun the mang am thaus that the wwol smaumampyhed sed and honty;
#
# A kisses lhatrâ€™d seedy,
#
# Being nourâ€™eldâ€˜€™d, Nwestas and snul,
# Mafint;
#
#  R
# â€™ddbeie, myo thes
# ----
# iter 13500, loss: 17.961518
# ----
#   chon reed
#
# A thith tay thand adileun will nied,
#
#  And nen-™edd be,
#
#  Storn,
#
#  Andene withy afite a o thet tered by t amo t and with sarirte wimo rot,
#  Sird por lore wint stoss;
#
#  Sird posntym coat mo
# ----
# iter 13600, loss: 17.872450
# ----
#  ifed lore wheek;
#
#  Nedure the stons ;
#
# Misldeegrere a
#  th lilg mes ceim, thou what thitwethas shint nnase chet meigne,
#
#  Natuusedwits af threm hte corer thou woge.
#  but remire whit cim hithe with faph
# ----
# iter 13700, loss: 17.799178
# ----
#  Here noag toy s c lore.
#
#
#
# â€is t amirit hsen with hsasted vesuimere, wisser,
#
#  boghâre lov-.
#
#
#  Vongune aabips to live wlo hstâ€™d hein,
#
#  More withyer sive nact;
#  I˜wour,
#
#
#  Hut aboveld-f
# ----
# iter 13800, loss: 17.664063
# ----
#   sypses sies me-boung lied hith kisser seepkith kith ssitl weth,e  ao his samith hsesh shem a
#
#
#  a
# d th the corounth shtâ€™d;
#  Mon mous tor hon loght ferhees and seud y thred y thilf thos aso hilt
# ----
# iter 13900, loss: 17.604856
# ----
#  sthy steddeing lor âse;
#
#  Hur,
#  Mon monhsenaVelien hie thaked vor  rou knonun wim.
#
# â€™s thas laken hos mpant flirl akeprnt steref, wimsis th mort shekâ€™dlem sote;A thre lovely;
#
# â€ill tere any the
# ----
# iter 14000, loss: 17.555807
# ----
#  whous lovthâ€™mpis sfas case aro kill net seean heen o boghâ€™d lous tov, fove a o pins receet shere begnte;
#
#
# â€˜The amaun ton d
#
#  Hut ato:
#
#
#  Sind
#
#
#  SNeer,
#
#  And yothendecg;
#
#  Anu i
#
#
#
# Ad hourint
# ----
# iter 14100, loss: 17.470860
# ----
#   priere wheld,y thike, nyo;
#
# â€˜Then;
#
#  Naties re their, the ton loug wempang emy thwe tyn sied liver rhere,
#
#  Vdoce pang menle chllw:
#
#
#  R
#
# â˜Sint rere an hies s andoug te theen Beid tyend hous thy a
# ----
# iter 14200, loss: 17.425388
# ----
#  ipk-thandepn withy,
#
#  And ceasaoNas uith mafe,
#  Asdeudoserâ€™ldes:
#
#  Stane ky
#
#  Racs;
#
# â€˜Thre lovery thefâ€™d Adeire, pan noathâ€™edddyng amour lo™s fallay ste-buath seishem an,
#
#
# Htendabuum,
#  bu
# ----
# iter 14300, loss: 17.405269
# ----
#  ad hee wtose;
#
#  Sicer thy seod hour that feikhied begnu â€™s chil sadi™ lowithy ath palMy,
#
#  Hunty;
#
# Ten kicl an ty,
#
#
#
#  Saren thet stise, m
#
#  Seiret thus shite and sed,
#
#  More with fseswemaunto,  hi
# ----
# iter 14400, loss: 17.318671
# ----
#  .
#  mike one-beguite loverer,
#
#  And se Sait ow-chenr staniit shiesas chour be,
#
#
# Heres,
#
#  And liug steu wim ht stenley seidein loss tamimle wist ssorme wemlor there lyâ€™m, p mebeethâ€™d satie, monu th
# ----
# iter 14500, loss: 17.190659
# ----
#  ere;
#
# Mi˜˜Nanan  wlous to aliwissemy tor the thyt move-buins ssistasve, bye,
#
#
#
# Adece liss fwistrevelfâ€™dter indend yet not core a t as oldy,
#
#  Neekely thakef ano she to thandepn ymee, wed,
#
#  Mor
# ----
# iter 14600, loss: 17.064665
# ----
#   t
#
# A nin that snt than safâ€™d to tore bowe cloy sted int mpare.
# oy to whanty:
#
#  And ye sing ches;
#
# A chot thont, bill hetâ€™sleawhet asoun noping het thand re the lover,
#
#  Roarishe lovewy ald  no c
# ----
# iter 14700, loss: 17.004866
# ----
#  bekt-t™one weeddered he stâ€™eld-wather thy Hamipl, amondint reenwy,
#
#  But râ€™esAnd hont she thasulthes weth belty, byr, far toun arted dain thithâ€™d satiet mading.
#
#  And ye the buathevâ€™d, anus th
# ----
# iter 14800, loss: 16.953056
# ----
#  st chore pys sise nome tunte that mâ€™d ty te lokt lore,
#  hene chasse;
#
#  If tho wimit more aon he wieldy andon swed abuathes whit matedeim  he-bem wasted os thor thas an, wil, monhse pye kict timied y
# ----
# iter 14900, loss: 16.941993
# ----
#  tore wiet maustte;
#
# A dover ros: whot hathegd
#
# Bere-facâ€™d ce will seing was tove may thes this, o hithedâ€™d to thenty;
#
# Berâ€™ tcy leen wasted hacle wiml, nowe a bouien ho,
#
#  Masid to thod ,
#
#  Modd
# ----
# iter 15000, loss: 16.861269
# ----
#   tpo thous thy steneree, wit sheity thinf flop;
#
#  Naduint mtheas seuc,   ore t an ceelf thit ho kipsist thau wissef asted in a t Io fiple-oweng he thasuiloy stove,
#
#  And pisith kilf thanasead clo ghps
# ----
# iter 15100, loss: 16.795326
# ----
#  fat het tengen loug hisses shakem onin whit cte;
#
#
# â€˜And he lor thyer
#
# Herer theed,
#
#  And ne anddeneity hovechor, thin,
#
#  Natint ssatr theve, wissesse;
#
#  Hut seekgVore,
#
#
#  kecmit ste ting mo
# ----
# iter 15200, loss: 16.648933
# ----
#  ad rouind see and ro fiar tey tor thee woll angn them colo wilins ssesurâ€™s fret ftore log;
#
#  Mo thy s that Vbee any thy ste thae am wheet ma
#  thithegny,
#
#  Mons abus Vorty thie an ther than seem mopa
# ----
# iter 15300, loss: 16.486545
# ----
#  . gno the tin hean, the r
#
# Malingny  hosn thuekâ€™s dayn tod suitor stes marldeve to wemirs shove;
#
#
# â€™d rme long wather famirl anty to alouchsee wee, and sed,
#
# A kith fat thit htââ€™d, boer, f thef
# ----
# iter 15400, loss: 16.293236
# ----
#  oril rair saed re thaâSerem pong herâ€™d lipis chie,pise chee lon wonth af dour tos swethale wreire whitpy: fire.  ho will nae, boghâ€™d han aind setenvy,
#
# Bert,â€™d rmadong to llovees amev,
#
#  But,  a
# ----
# iter 15500, loss: 16.099582
# ----
#   Hut reifâ€™d beddee-bow;
#
#  Saideth thet reikeshes llong mor, fore wereeghet, borer, mwithyeâ€™dlorl-thonalrâ€™d pim lher pyslesabe;
#
# â€˜Thekely thenalogs feis;
#  If thos shorey wimren, arer bouthy,;
#
#
# ----
# iter 15600, loss: 15.903233
# ----
#  , and boeden, wecl rath thasseis ree,
#
#
#
# â€˜Thenree witlefwety thef and he r
# o kn
#
#  And le, moukn wore loy,
#  theen ton habem soathen, more a buse lone winth kith amat :wore beve-cahar fatly,â€™d,
# â€˜
# ----
# iter 15700, loss: 15.808336
# ----
#  sty: Sice,,
#
# A the love nome the chise;
#
# Bere an yno kng te kier a f witheâ€™s kirlrak-ouisse wath thy ledong weety:
#
# An mweth thas llevâ€™d pis thy lips alipl hy,
#
# Bith ferreis cher,
#
# A kils shet, s
# ----
# iter 15800, loss: 15.854941
# ----
#  wisse, bopk-fwâ€™t s anind hore wit this shakest csot ratimoukn,
#
# A she tod him thandeign Voml, marg theve,
#
#  Mrem anin tod to the loverneceâ€™d seator roukng wend rort sosthâ€™d, bum, pil her,
#
#  Nadi
# ----
# iter 15900, loss: 15.725687
# ----
#   thy sepas thy loveg heecherâ€™d tond ret beed, buse thae dire that therâ€™s seile and s tisnimore that the kiely wothous ,ithe boglp chplror:
#
# Mokeely,
#  Iind lo ghme ton lyes wetpon,
#
#  Burt fath tr
# ----
# iter 16000, loss: 15.662029
# ----
#  ied lour sead honty;
#
# Ten acguthe;
#
#
# â€˜The ilove,
# o Mo kinth mabous fareint some wegan with f-overhe;
#
# Makire the thas llern
#
#  Ranery thy steur bum thas thist cras shat abt ste;
#
#
#
# â€˜Threiboe
# ----
# iter 16100, loss: 15.705537
# ----
#  adait storer th thy lrover hs to come myo that tofien shau weeld-facâ€™d hy thasuithy lrore auboud
# Te the shaked ag thas ato wim in love.f to s n she-un hith fâ€™ th m at tove that this;
# â€˜˜whelf tre
# ----
# iter 16200, loss: 15.780512
# ----
#  .
#
#
#
# â€˜And piset rothe fies;
#
# â€˜The tonldy,
#
#  And tind on nont a
#
#  Hut the fith fwesumakelike wimly asour bouts;
#
#  But ratloverhâ€™d sn thakendossust manmy,
#
#  Rone-boughme;
#
#  Hutren wilw-tons
# ----
# iter 16300, loss: 15.689354
# ----
#  e rote nile thone, myas that made loug ar bun withy she that mading
#
#
#  Rone hafedd kith kith seilo helr to aHlve whephef thiet not lous tor heâ€™d thal
#
#  Sird nofkeldâ€™d ho the shere; a but  wist
# ----
# iter 16400, loss: 15.576292
# ----
#  Hefer
#
#  If theu whothâ€™e nan wiss f,y;
# âThirâ€™ hichse manguie thot theet, o thy mrouts fermorâ€™d tan anein  ho hus keghe the ton hing hy are one-boughte sied lore whee am tult meim thy sâ€™s sach t
# ----
# iter 16500, loss: 15.439077
# ----
#  dAdd huimtor ile-wathre witl hâ€™,
#
# Making will nleng to shis fleng wissel kegh meign the with faphre witpyses feahi;
#
#  Mon hset,
#
#  tore wissefaâ€™d ind setdâ€™d he the r
#
#  Hitp hitho w
#
# â€˜Nacsres
# ----
# iter 16600, loss: 15.424936
# ----
#  s orireâ€™s cmaserâ€™ddâ€˜Thren hy mape-bow:
#
#  kcen,
#
#  Here ano thasuuto alignt,
#
#  Rofer,
#     his thy life with falf shem ywes oweth varield yhre lor thors faahid on-ly the kevade whet meithevâ€™dl
# ----
# iter 16700, loss: 15.339204
# ----
#  moaked,  Hepret sedie with kisses lart as ouin h theed,
#
# â€˜Thes luimipst ;
#
#  Sicthek;
#
#  ˜Vald hore with shat no where,
#
#  Sicd,,
#
# Mafiuty womecâ€™dler,
#
#  And ty at o Mous thy seed heu wiml, mous
# ----
# iter 16800, loss: 15.263823
# ----
#   seind lo hit siesuss: ping himse bym, fowhet ntiss taritheid dove a s ty thore ceilfe, whouf llesbasleve;
#
#  Saither â€™d le thase; o.
#
#
# And be, wind his lwedteoneng hem ror lwes saver
# â€™g ro them
#
#
# ----
# iter 16900, loss: 15.125311
# ----
#  ore devem with thake; opash faisalt maugnty sere loval, more and hit,
# â€™sn.
# Monur thorâ€™s kilg tramiethek-cmokerme:
#
# â€˜Voveraer sied tom clol,
#
#  And live thyes that sedlanune core,  he iher
#
#
# ----
# iter 17000, loss: 15.002496
# ----
#  ad addile loy thy to aHlous te tomm myeth veat seitha saceucherâ€fed noling r
# odint shith :
#
# Ten  but shord, I
#
#
# Anuswesne coae the myef fltane winty the an hid sede an hith thaes an homred,
#
# Berelf,
#
# ----
# iter 17100, loss: 14.874717
# ----
#  sesn:
#
#
# And lonthekimpeng as thy love;
#
# Ten nonuh thelderemwithe, nouin lonen wimad to
#
#
#  dilild,
#
# â€˜The done mce live fem rot ymleva
#
#  Ant asrt thaaireddy thou-by, fois r
#  tind bousr,
#
#  Rove-
# ----
# iter 17200, loss: 14.766868
# ----
#  orer theire with shrthe the lies lisseddâ€˜Thire, ar ther t
#
#
#
# Hurei with liplle,
#
#  If the whore, whet madin,  hitheind nold-facâ€™d h owen,
#
#
# â€˜Thendee, wisto the the to thoughmeie them
# be-boTen
# ----
# iter 17300, loss: 14.676483
# ----
#  Here done ore roud lore whet stoss;
#
#  Sirdenouin the hous tos thy sedow-thanty;
#
#  Scort aseald houd seddevee whouts;
#
#  Hutres fave-fach;
#
#  Rone;
#
# A inosun wise white wins rauim thes thasedlove,
#
# ----
# iter 17400, loss: 14.586061
# ----
#   hine lovegh serean shein hiss feem tos thy to alouu  wilcen feing hemphses and not, horg  he monN lowith thes theire man loy staisild home bossss;
#
#  If thou shous ton his thy the love coer â€™e dlpne
# ----
# iter 17500, loss: 14.443597
# ----
#   the sue and le, and nond hred,
#
#  â€™d, kith thaf the faere fire coath;
#
#  And ye thasud onmy,
#
#
# Andâ€˜Vout lo€™s fadisned nonsussese lovâ€™ suveat shat thustere chortyâ€™d he-buathes mmasimart thakek
# ----
# iter 17600, loss: 14.382058
# ----
#  with tfat keit lert them abitheed hourt,
#  dong-beddeema
#
#  Here;
#
# Mous;
#
#
# â€™d, a™d vere wito hsttâ€™d buseilous to wit slesty,
#
#  Mive and setey, wid rom kere fous reie hie that slisthe;
#
#  Iâ€˜ghetpye
# ----
# iter 17700, loss: 14.276769
# ----
#   prouthenmict choy fore.d nomld hy;
#
# â€˜Thre abounssere,
#
#  Scith that ssesy;
#
# Tendovd-cwechre;
#
#  kill ant osed,
#
#  Mon hith fâ€™t satheen ylous loy the thaser thin,
#
#  Nati;
#
#  And ceed,
#
#  Mod hl , move.
# ----
# iter 17800, loss: 14.325522
# ----
#  ieg sea thint by thy tisted an anu nowisted ins lous pile,y seaek-taogr thas lint weth loang, thilf loret lim.
#
#
#
# Ane lovely thane yhmpret heitwast stanek-caslceremais le-bowtro wile-thane and,
#  Monr
# ----
# iter 17900, loss: 14.300878
# ----
#  ad it fwen,
#
#  â€isth tisted an shause,
#  Mo t m
#
#  Mad unth thaed,
#
# , And sedi˜bus rwitsrtpand sacher thorses, Iâ€˜Thir,
#
# â€˜Thre suo wilt seathevy,
#
# Beisst srel hit,
#
# Beid,
#
# Heithes keng lorâ€˜T
# ----
# iter 18000, loss: 14.162479
# ----
#  .
#
#
#
# â€˜And nekes wempang as she-
#
# â€˜The tom hselt muit hhe tim onin hog to thasudave ton hifle keth Isaaf tod to the kauc
#
#  buker thee, m
#
#  thane bus sted ayn leve;
#
#  More and nos chosneny whes th
# ----
# iter 18100, loss: 14.030479
# ----
#  enin,
# Mle-bwerte, o chsenty;
#
# Ten, boughse thasum hs to wheed or thanendaddHuu thathyâ€™d co kiss câ€™d hun hef neity;
#
# â€™s seat the lover tho wemiket theed oy ton lye thos theef he ton;
# â€™ddein to
# ----
# iter 18200, loss: 13.990144
# ----
#   liunt horl,
#
#  Be-bu:
#
#
#  Mort loraphet,
#
#
#
# A bucâ€™e hit hrâ€™slevâ€™d Adeigno, who kie, py sef tho wamiunt moihre, moun withpveseve ain tond yed he thaved westo aroudâ€˜gwith sht, fMore a bigrâ€™;
#
# ----
# iter 18300, loss: 14.365693
# ----
#  , and s te comld hort,
#
# A tand pasle wim.
#
#
#
# Adtue wignty secâ€™dlevâ€™d, aHne an More ty;
#
# Tendaboughe,
#
#  Socdâ€˜gwinthâ€™d, bun ame-caâ€™d, aHins rafein hies cee wheu wile doret as sith varies;
#
#  H
# ----
# iter 18400, loss: 14.393691
# ----
#   with variethas lpather mpit shenthare;
#
#  Hut keife to sill sset satae onis thas anonl shem with saes mafe a bitwâ€™d do but shon, meire that ssed to with thes thout,
#
#  dird akd hem Venec-toN:
#
#
# â€˜Th
# ----
# iter 18500, loss: 14.235309
# ----
#  gome-bualiepretpy;
#
#  buishe ton samare and seding he lovarhem,
#
# Helrâ€™d lakg the homs tro she sie, m lout
#
#
#  d botheed houn the faed
#
# â€˜Thet as the worec,â€™d, buche;
#
# â€™dd buth,
#  If the wheo
# ----
# iter 18600, loss: 14.129330
# ----
#   the tand lintyes aty:
#
# A vorld hsit sted and nour
#
#
#  Vykety tost saket o thovelf,â€™ thumafed
#  Nutimour to asill santy;
#
# Ted to tand nean went seth secllevâ€™ cvont stose;
#
# Bith râ€™d bith ssases;
#
# â
# ----
# iter 18700, loss: 14.063909
# ----
#  ips flore ceephet meigne, whirep noreel hart seisle with kisserâ€™dlee wit rhe-boughes to all yserd, an, ,   r
# â€™suf tros;
#
# Asun hith saind no kith twethan;
#
# â€˜Theu his t ssere;
# â€˜Vond yto slf,
#
#
#
# ----
# iter 18800, loss: 13.886053
# ----
#  ad cee with câ€™d be ches srore;
#
#  Mons an not rodt sMore that ther ton hint med
#
# A thee dorem kee wit chil set,
#
#  But ritheu wilrod lorn;
#
#
# Ten abougher t
#
# âSire loker theiy th kisher, m wilis hrete
# ----
# iter 18900, loss: 13.754324
# ----
#  lis shaked ibot khe,
#
# â€˜Thâ€s thane nomond sadiste tilean hee wist thas core that the tom hphstpyâswetses:
#
#  Sied
#
#
# â€sen,
# Mosu mong loss tâ€™d, ar thee lonket,
#
#  panu love wheius d
#
#  kere,
#
#  Sacâ€™
# ----
# iter 19000, loss: 13.728220
# ----
#  ed, miynt,
#
# Beire ling ald nanid tod lim l heke wocgres ping mosres faphstâ€™dler lovely than love al she that ster keic llou lovero hsake,
#
#  Saith r
#
#
# â€˜Thre lovely the wove bore nghee done;
#
#  Naduc
# ----
# iter 19100, loss: 13.717345
# ----
#  Hur tonve Vumied hon and ceed histeree with liptlâ€™d bith sore,
#
#  Saun bourâ€™s chemh
#
#
#  Singunty;
#
# Tenty;
#
# Ten Vbeein   ho toy thou wond câ€™d tr the buthem ree, wit hsen, at
# oMisse fle.
#
#
#
#
# A rilo
# ----
# iter 19200, loss: 13.659712
# ----
#   ad boghphses chanes thre lons rereime, limel nomes faver, masl seat ond-facâth kith shead
#
#  Stars that set thas psle with falf,e thous math an then noathen:
#
#  Nature bougher tond le bele an she thas
# ----
# iter 19300, loss: 13.644134
# ----
#   wio thy liprps;
#
#
#
# â€˜Thrt ;Morokssse;
#
#  Sird pade fwem an suce won hes loverpyeth keluath bem,
#
# A ling mo-fâ€™d Aio on doror thit foverpas thes anondd on wil, mouk-beire wie,
#
# â˜˜€˜nanguto wint ano
# ----
# iter 19400, loss: 13.613307
# ----
#  all vey meil  hons shekety thes rees any o o t anoun thous ton Vet short naam aseed he chove;
#
#  Nated  aaind his;
#
# And bMored with thasimliss tinl loaked wamius to tonleng hos wesiem sheke  han, oI mo
# ----
# iter 19500, loss: 13.483296
# ----
#  ,
#
#  Natuu thonsucâ€™d pane and no kill ame withevâ€™d se thaned Natied,
#
#  And tanddanu ton an kith mafe,
#
#  Saike ty, ping am luste,  to mwent seceen wilorhs seos to,e that the woth reâ€™d thuseice, th
# ----
# iter 19600, loss: 13.365613
# ----
#  ip™sted vorl hae,
#
#  Natur tedeing heee anddan nuito woaihghs lave,,
#
#  an nond ind ndlifle want maucarousefaree-bushilt the wom cher,
#
# Asun his fies lov,
#
#  And pingustedaire tonld hath lo€™s piss
# ----
# iter 19700, loss: 13.240062
# ----
#  ad
# â€˜Thsef tam tod
#
#  Mide lore.   with het fiere lover the lovert thorm,
#
#  Rose-cheer to all unouu pe rol lwe;
#
#  Naturmes;
#
# â€˜ghis tf tref, tho hweth fier to wher tong hses faice ton susesween sh
# ----
# iter 19800, loss: 13.244450
# ----
#  preth bety:
#  An lye, fein rto tond pane choverpatheâ€hitreemadddonu hit to hied,
#
#  And Vekike lovely than, mowed he lave, whithei thousam beps tariety;
#
# Ten kiclrâ€™ hea lous mort thored hy them pe la
# ----
# iter 19900, loss: 13.332754
# ----
#  enly:
#
#
# A rold-cowither white an linle ghsle with keile hondes thelf ree chou went suimelf treedy s omius ping thel ame monmly thour
#
# â€˜Then mrompysteddisg: pan and snis thou but sertedeignte;
#
#  Bein
# ----
# iter 20000, loss: 13.250345
# ----
#  Hur to whoudâ€™dle, thore, w th kit she tonm heith sermee r
#  thee,
#
#  Nate a bule wher,
#
#  Mori tyste angnen noghe with that setorei tor to that oed huimto thonty:â€™-nâ€™d hitpyses ksat oIM mike a
#
#  Se
# ----
# iter 20100, loss: 13.105353
# ----
#  d,y;
#
#  Natuind loukel yhlt alo wecpherp,
#
#  Naducgret fielf hm as core;
#
#  Nat ceilo woth loat suimore core adod th thy seddlun sher, ar kill wost thint amdil hsedd
#
# Here comprper,
#
#
# â€˜And he tonl he w
# ----
# iter 20200, loss: 13.011769
# ----
#   weng tr
#
#
#
# â€˜Aud hones sat and lous to aligsâ€™d sumakiclraseinwespant meithev: aMond boushy;
#
#
# And thaustre loves tanldâ€™s c mowis timr boghâ€™d seddHeumami
#
#
# â€˜Thre a bule wort a wilepy am s
# ----
# iter 20300, loss: 12.933129
# ----
#  hith kitlesa;
#
# â€˜Thre a bues,
#
#  Saike thaset oned,
#  sios thin,
#
# A chot r
#
#
#
# MSeing weety, thild pas core tond lore long tho with rime theety,
#
#  Hure any hiss thas and hisser,
#
#  Saing  im S ad cot  h
# ----
# iter 20400, loss: 12.764382
# ----
#   to more a
#  is sins caâ€˜Vwatind Adout thy iro thee with falorâ€™ sre, phon,
#
#  Stire mafeâ€˜Ther thys feity lare ado Slcert thang chor pong keer thy lips with feor thel amot cloy thy liss aadein lo ht
# ----
# iter 20500, loss: 12.796408
# ----
#  ferere, m hith kill akeedweng ar ty:
#
# â€˜And yrte abuse;
#
# M€˜Narerun,
#
#  And ling lo aste; oat theid dovour tis tyn; mat ond p˜mielde-bouchse, maus tissiereshes:
#
#
#
# â€˜Threr thorâ€™s dabougher to do
# ----
# iter 20600, loss: 12.715475
# ----
#  ad taâ€™d falech:
#
#
#
# â€˜Thet lore. thous pis twemtonve, the wheith laabut,
#
#  bukerte, o piss fartaâ€™g theed
#
#
# â€™d seding wisld wisne bemsendepong liss thtat
#
# Making thy t ma tosun,
#  hen feif lo
# ----
# iter 20700, loss: 12.567175
# ----
#  .
#
#
#
# â€˜thâ€™d, kith te;
#
#  beive, momis cherâ€™d beed him, faind nto his theety sesu m
#
# Morin hims sheed,
#
#  Mo rit, thailoy tho wheree wint dover,
#
#  tid none;
#
#  And pasume,
#
#  Mori a boter,
#
#  A
# ----
# iter 20800, loss: 12.403581
# ----
#  ed ind lore weot thas pon ho whet omore   a
#  to sachutrâ€™d abus ceeand
#
# bu-bouss;
#
# â€˜Thed borer thy site namer reee wio hre whithâ€™d keld,â€™dâ€™d bathes:
#
#  If thei the tond pane an, chaked ao hus
# ----
# iter 20900, loss: 12.283809
# ----
#  Here, aroning o the pile., with tan ane the pypr tr
#  but theinty:
#
#  but ;
#
#  Hun aty socghs seeny to align,  hos llongyhet rith keile what
#
# Making thes wetsaseane bucg trofe,y tore a n ly,e,
#  f rier
# ----
# iter 21000, loss: 12.224931
# ----
#   honty,  hit oy thont ssitr
#
#
#
# Aden humety,
#
#  But rore lovely thoniho hristermâ€™ lius lefe,  haun stosn;
#
# Bere lovert momarMore that heed,
#  hiss chame
#
#  But rathe whous ree with li€™s fimis sete;
#
# A
# ----
# iter 21100, loss: 12.191296
# ----
#  s hy t™o thore ado t ome lovey,
#
# Makint stored his thas fwath fephit tom ce the tond pors thy lirishe-begn lore lys;
#
# âe˜Thus lwath that madenrath thpling he;
#
#  Seungy,
#  iro Sild he an kith thasi
# ----
# iter 21200, loss: 12.190858
# ----
#   hin,
#
#  Morer an suth
#
# Beike tyâ€™l hodt
#
#  Sirguntyy;
#
# Bere, and snec-câ€™s cheth abegngIâ€™d linle where nover rith laove;
#
#  Nature lang meung withy;
#
# Aed he the and snd boughse mavâ€™ ondâ€™d,y myto
# ----
# iter 21300, loss: 12.115456
# ----
#   tro the tond het thes afe thonsasce, thonss;
#
#  Natu;
#
#
# Ten in lo rpole a™d ty thes seimhpret fait a
#
#  Storn seadeigh thovely,â€™dâ€™y to as silf cher ton an kitr sadleve;
#
# A theed,
#
#  Mo the the
# ----
# iter 21400, loss: 12.071875
# ----
#  ife d
# â€™d,
#
#  And cein;
#
#  Natucety,
#
#  ˜Vathet adoni wim. boud hunste, and luitlovâ€™dleid tham to wisuito hesterted an suchrte bit store thas mpith faril, mloret thist thinmpan;
#
#
#  Huthe wimor he she
# ----
# iter 21500, loss: 11.993796
# ----
#  ad tadeinun histp, mweth ferpolt red he thae cove a n wimte kitses:
#
#
#
# â€˜And ior th the r
#
#
#
# âTs;
#
# A t mour
#
# â€˜Thit short sasse a
#  thesusaf, himl, mlor them keen boghâ€™d to s s theekâ€™d abus cee
# ----
# iter 21600, loss: 11.857860
# ----
#  .
#
#
#
# â€˜And meed,
#
#  And cere wao thon seevâ€™ ling ht thisses:
#
#
#
# A myuthes pleme beguilius  withaâ€™g hous began and bedty;
#
#  Vonunty;
#
#
# And thake;
#
#  Hut rode long ay them sedenekind adi€in kein  h
# ----
# iter 21700, loss: 11.763881
# ----
#  rekely foushrâ€™d, ount,
#
#  Beer beor lore and ste ty as tMon chere piny ther beer,
#   hitt arom treed
#
#
# â€™d satiot coris the wotweed he pong hses famithess;
#
#  Nadike a d onod choser, thou whoth,
#
#  Mod
# ----
# iter 21800, loss: 11.634403
# ----
#  Here come mon ane loves,  ty theree wroety thar bepush sheipr loath pilor,
#
#  Rover thou wilt decghith kithâ€™d se that bee ond pil hher,
#
#
# â€˜gngn hat meitove chou wondlevâ€™ thus thy levecâ€™ saus;
#
#
# ----
# iter 21900, loss: 11.535264
# ----
#    buste,
#
#  tind pilt n ang lolf phist beisere pyshef alish rer.
#
#
#
# â€˜Thricâ€™ to with theed,
#
#  Mor ty the and €g thef an them aby, his love,
#
#
#
# â€˜Thilt thas angung thefwedA beee, m o thore
# ----
# iter 22000, loss: 11.505025
# ----
#  r thenuymorgh their this fwath kell aty slorerâ€™. ome love;
#
#  Sirgumt a™dd detorlel swet ond pee wit, ma
#
#  Sire winll sakth: amissedâ€™d, tomein his thy tos thasucetan tove with fore,
#
#  And hed
#
#
# â€
# ----
# iter 22100, loss: 11.633434
# ----
#  witr thakilif, thy steed,
#
#  And ta may shis than hir tond he thased sed he sith varied bus sheve;
#
# Bikere: withee with felrâ€™dleew
#
#
#  Iâ€™d, a tond Ane that madens anour thes the where,
# â€˜Ther tone.
# ----
# iter 22200, loss: 11.719102
# ----
#  hstâ€™dleed yst thusasene lover rathy;
#
#
# â€˜Asd to the saddloguht thin,
#
# â€˜The amnu lovâ€™dâ€™ he-buth sere;
#
#  hinthes:
#
#
#  And le-beid s chtrâ€™s dabouthe:
#
# â€˜And yet noth that th thet kee an thyss
# ----
# iter 22300, loss: 11.723853
# ----
#  efe,
#
#  Sicrâ€˜ghinie and nnle-by thy lips haf thonalo wheimpus ton loy tov,
#
#  Ronghâ€™d thus thy seddoreth sat anie, wit hsece and satdâ€˜ghur,
#
#  And livei cloy thy to where,â€™d bith vemike amous
# ----
# iter 22400, loss: 11.618811
# ----
#  ad taâ€™d and bust ating cith beghe thos llosse with ssas; timodd he: with serath la€™d, thang to lis tfyeth fart chofshses;
#
# â€˜The field wempare ,
#
#  More with Istein logst, secâ€™d to s t lor
#
# adin
# ----
# iter 22500, loss: 11.488815
# ----
#  .
#
#
#
# â€˜Thtaâ€™e kogh
#
# â€˜Thre t ynoss as on, mouk-borer, tim him.
#
#
#
# â€˜Thith ferath keil hm thoe coss to woo kil hs;
#
# Being wortâ€™™ dorondHes ree, whiety secret short as tonsunt mecghisiple whe b
# ----
# iter 22600, loss: 11.328818
# ----
#  erer hs;
#
#  And ty ati logsumpâ€™ sevâ€™d he lovely than a n seoden,
#
#  Stae ton hith thee with kee,
#
#  Natureed bous lord,
#  Iâ€isne the love,we,
#
#  More thasud os thas ther loy steâ€™d, donis rout heid t
# ----
# iter 22700, loss: 11.211058
# ----
#
#
#  Saice, thou wimeed hom kein,
#
#  And ceef  hy at main that mad-cacltare the began moussase with kissed sedwithphp,
#
# â€˜Thde lovely thyr,
#
#  Rosint thane any thee love a
#  He live. o wimre t am cet lak
# ----
# iter 22800, loss: 11.137878
# ----
#   An log phses fave-favhes arampas fwathe worith seilinghe theâ€™d beingy, reâ€™d po hit, Iâ€™s hrethee hissessesAd,   o Sfed wetlove-faâ€™d ndanin, mMonin him, r
#
#
# A chet feilo herpasess:
#
#
# Being  a m
# ----
# iter 22900, loss: 11.139988
# ----
#  m an thae done, weth thes mlorâ€™d Adonis trem shaked aboususher to al wend hon,
#
#  onor tore with serast an hit chere wore love,y hovme;
#
#  Scath cmat an sies ree with fersed hau wove a o thee,
#
#  Staed
# ----
# iter 23000, loss: 11.047755
# ----
#  mpaght for thy mee;
#
# Addlingn,
#  o tind hom woth kisser seem wilf fliifes tho wemiut
#
#  buke thy troMhree with thy seod hour to sofe-chee an ly llong misle whore cempisser,
#
#  Saice lively: â€˜T; bis
# ----
# iter 23100, loss: 11.078421
# ----
#   tro thithecâ€™d bistr;
#
# Being  hith,
#
#  Nature than aodynd with hef thou konts beg
#
#
#  fade-beice, maun seed he the and silde he whoui yot r
#  tond re the bogghtrâ€™d but noweth veond he thas clenwhen;
#
# ----
# iter 23200, loss: 10.997096
# ----
#  iets Adeigngheem lo whein he whithein s oun Vendeins asadeith sramr
#
#  Râ€˜And he that ster she togs chere,
#
#  Seicis flisesy;
# Beike a
#  th theed,
#
#  Mor the;
#
#  Sire andy  s o. n begh seove;
#
#  Storn; o to
# ----
# iter 23300, loss: 10.965404
# ----
#  ad taâ€™d, bem reed,
#
#  More with feakirle fald rot hon kee,
#
#  Huthâ€™d abut bee wothei,
#
#  Monleng morn   m on tym thee kore.
#
#  Mo ming westoy stinm an,   o kill secresl hath ain lis tro the bega
# ----
# iter 23400, loss: 10.885826
# ----
#  .
#
#  Stinu that cees:
#
#
# â€˜Vorg
#
#  Vonen an hin set,
#
#  And panu ton sied ho that and ceedosses lort thors,e and   o t m ar to them
#
#
# Making thothed, mon his fiss lean set tove love,y homre,
#  Mo t
# ----
# iter 23500, loss: 10.765439
# ----
#  ort thy staitim,
#
#  And leve;
#
# Adddido sit hhore,  hilf. the scorm,
#
# Being wisted ingung wissifer chos swath asitied,
#
#  And rein she-buseth sath kelp:
#
#  N
# âSeired hem  the myeth be, lor â€˜gint shorgu
# ----
# iter 23600, loss: 10.644300
# ----
#  Heid him, thoustof thit, thous meim,
#
#  Rones chhife, thou nowity the;
#
#
# Being  a  hin loy tfel sees an cet love;
#
#  Natitulais twenddoven han nag th thasedAty to an he love-bouir pllout, twethad loy lo
# ----
# iter 23700, loss: 10.699997
# ----
#   addy loy leang to tom his lpistpr, bore.   y lo  wot shakes oathâ€™d, bum thou wilty, o to thee dope;
#
#  Nature be,
#
#  Saing to alignt, s th the mymemhrâ€™s thave;
#
# â€˜Theed he thy staneddoug uith llas
# ----
# iter 23800, loss: 10.776269
# ----
#   with sermasted, an the withes anow-to the and sipl-facsed, bute nabe, wissee,
#
#  Staen an nung  westoy thoss marmorty
# â€™red,
#
# Beike a bild pil ht thove, Iâ€™ll snofe mys thy lfitr t
#
#  irt cared he t
# ----
# iter 23900, loss: 10.714665
# ----
#    hous them kein love,y hosus wethan ase the myety,
#
#  But rmameed nodis lover rorn;
#
#
# â€˜Vouchsase;
#
#  Nataceeddysem them an none a don,
#
#  Mond no them am
#
#  Sickrer
#
#  thar buil ches shakerA thausty;
#
# ----
# iter 24000, loss: 10.605713
# ----
#  s thaniytr f ous to withandaug tond he sied nonty tod s t
#
# Makinghe the saddlp-n,
#
#  If tod hogred,
#
#  But rathem am ce laine bint as that sses shour
#
#  If-voak-chredâ€™s dabe-baker.
#
#  Icâ€™dlesakhe and
# ----
# iter 24100, loss: 10.602586
# ----
#  iet, tay the saddle-bowhhedeity ser athes:
#
#
#
# I˜An nons toy the sind pore, mongut stoa
#
#  the, with thake,y hissedd noss;
#
#  And leun And with fered with thaslovean ho the ty:
#
#  buing tos ton ly, ero
# ----
# iter 24200, loss: 10.586081
# ----
#  ad reithee with leake a m seldey wetham and he plele hred,
#
#
# Adeind hont shaker ches shakes boekwâ€™d ynt onesy thaniseer,
#  t anind ymephid maouth ase hee and hisser withein honty hy the seddle whel
# ----
# iter 24300, loss: 10.494570
# ----
#  .
#
#
#
# â€˜And makertey;
#
# Ae lover thel arod to line, with frem roodd
#  biety;
#
# Ten Vecon hothee witses:
#
#  SBut rore the such ty doy san she that mothâ€™d, kedadbcgheen that maed being nmouk-rted abcesui
# ----
# iter 24400, loss: 10.375219
# ----
#  ithy than han,
#
# A r o thee, with werpases keoat seit core,
#
#  More the plous to aloung them cee ay will heet sher,
#
#  Seisses shike lang he;
#
#  And toverpasted ind himpys;
# â€kenn sheke the lyve;
#
#  SRos:
# ----
# iter 24500, loss: 10.252897
# ----
#  Here comer, to alir tovâ€™d tan aneint them,
#
#  Nate a but lo€sees
#
#  Saitr ping as shem  manin,
#  oste a thet ato all semake a boushâ€™ hiver hst teindeivore,;
#
#
#
# Ad he love;
#  ™in love;
#
#  Mo siss
# ----
# iter 24600, loss: 10.259221
# ----
#  d,y thysseâ€˜€™dle;
#
#  wheâ€™d beind shekreldy,
#
#  Natur tare ain sil, theef,
#  eade thyesasMane wisten an shee wotheve, arHe.
#
#
#
# â€˜Thite cheike with fremly sted,im ton lyen,
#
#
#
# â€˜And eadHe, abis cas
# ----
# iter 24700, loss: 10.274906
# ----
#  shead sed uilihu k thes movthee,
#
#
# â€˜Vorget thist thin,
#
#  An lo wheman lou lovely,â€™d A lish rorer ror slesuan hon amarn wort seef thed,
#
#  And loun  hons as owity seoushâ€™d bith fore,
#
#  More with
# ----
# iter 24800, loss: 10.351542
# ----
#   lovely thanihorâr™e a n le thinllevâ€™ suvem hem kelf aro the begree kisse wimoun nom,
#
#  And peen the lieg lous to mleek-bov;
#
#  SHunsase:
#
# Herdâ€˜gsunty,
#
#  And yed nte;
#
#  Saike ty tim ht thos lwhet
# ----
# iter 24900, loss: 10.305813
# ----
#  s fart seire with frest
#
# A shith an, to all sat h ipllovâ€™ thas tf tpistrâ€™d faisipl :
#
# Makint nay,
#
#  Sucthre wilsers ssesaito with thasieddeignes ;
#
# Hes;
#
# â€˜The fielf varithan lovely horg the
# ----
# iter 25000, loss: 10.266355
# ----
#  feer meor meen pyle, m pit thy seind with fert thorsese: wmothed,
#
#  More with sechef ping he;
#
#  And like a
#  them ma
#
#  Mo nin onleng amde the;
#
# â€˜Thtendisesy;â€™r tang make and sit ing nomesnef wtheed
# ----
# iter 25100, loss: 10.200862
# ----
#  ad ife fierepy arire-faver them ma
#    o nd humee whoreen whtree withef, th sere;
#
# Hererâ€™d bimer store want chase;
#
#  Seing with shek-boughre thanse;
#
#  at deimmase and tand paser cereen with foriser,
# ----
# iter 25200, loss: 10.086398
# ----
#  .
#
#
#
# â€˜Threiro kitr mabe-charatyy,
#
#  Natred thy sece ,
#
# ...
#
# â€˜The field he lively sea
# ----
# iter 493300, loss: 0.528445
# ----
#  rife,  hisse f at  tinld  hit
#
#  buke lo moug hre
#
# Here come and sim, Iime lin,
#
#  Hunting he chee with kitsess;
#
# â€˜And yer red Venus mathis;
#
# â€s;
#
# â€˜The fieldâ€™s chief flower, sweet above com
# ----
# iter 493400, loss: 0.634787
# ----
#  Here come and sit, where n cher, morus tey this fave,y recheâ€˜Ve rnod-nake;
#
# A chor align,
#
#  Saing rete whefey, Mor cor love he laughâ€™d to scorne chanean ny to aligng, thou wim,y he laughâ€™d
# ----
# iter 493500, loss: 0.634947
# ----
#   and he lavor, moddendengus thy lips alo wither shee wimpang heed, Iiling the pilf rpllf treer secherâ€™d sedll methssssecmem pis tf rtres than wilt n im, Iâ€™s them ay done ous bogghe, white with fre
# ----
# iter 493600, loss: 0.651843
# ----
#   he laughet feire,e,y rer, them red and pale withee-boves alt hsimllfe, thou wilt deight,
#
#  Rosk-ch vereed, monld he lively;
#
# T;nt asat
#
#  Saing pal wim, th thas ,
#
#  Natuimee;
#
#
#  Hunting hume  r to
# ----
# iter 493700, loss: 0.655474
# ----
#  aloun, f withevs as corer hs;
#
#
#  Sker:
#
#
# A kirle boudhhem and pale with fresh variety;
#
# Ten hiseen with hersess she, wrod hem and he lovech flefas angun eredyekâ€™d Adonis tried him to the chase;
#
#  Hu
# ----
# iter 493800, loss: 0.742050
# ----
#   prorle with kisses:
#
#
#
# â€˜And yet not cloy thy lips with loathâ€™d satietuinted, d
#
# â€™e and tonesy;
# Btiret feithevâ€™d nmare, whet above;hearut  hove man toy;
#
#
#
# And, am on himm shase thee wimpust
# ----
# iter 493900, loss: 1.015448
# ----
#  ips with loathâ€™d satiety,
#
#  But rather famish them amid ther famish thiffee fpeld he lieg lo the saddle-bow;
#
#  If thou w,y s s to aligng;
#
#  Hut red an one long as twenty:
#
# A summerâ€™s day will seem
# ----
# iter 494000, loss: 1.093165
# ----
#  ad taâ€™en his last leave of the weeping morn,
#
#  Rose-cheekâ€™d Adonis tried him to the chase;
#
#  But rathe howe o fmither an live any aib the sisess:â€™g. amaun lounthed, be, dore live,y rorne chanipm
# ----
# iter 494100, loss: 1.019946
# ----
#  .
#
#
#
# â€˜Thrice fairer than Hallacheth vean aro Sicr trief kisnt alo  hie the seddllg tym time-bovâ€™d suimeedyre the saddle-bow;
#
#  If thou wilt deighithes angun,
#
#  isus shake to alight phislo whem ma
# ----
# iter 494200, loss: 0.949555
# ----
#  e;
#
# Atu lively searit ret h bity ho€g to alignth feanirell compare,
#
#  Stain to allowe;
#
#  ta thee womld hem and pale with hempand ho s sishy meire lomas onis thiser shise and onlden:
#
# Maif to alo
# ----
# iter 494300, loss: 0.882551
# ----
#  Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smother thee with kisses:
#
#
#
# â€˜And yet not cloy thy lips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
#
# ----
# iter 494400, loss: 0.820362
# ----
#   kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an hour but short,
#
# Being wasted in such time-beguilingh their plenty,
#
# Making them red and pale with fresh variety;
#
# Ten kisse
# ----
# iter 494500, loss: 0.763642
# ----
#   he laughâ€™d to thee seveur mead hounthe, buaghe,   ome one lougheth voak-boushath velfasas sas;
#  If thou wilt deign this favour, for thy meed
#
# A thousand honey secrets shalt thou know:
#
# Here come
# ----
# iter 494600, loss: 0.712127
# ----
#  all nymphs, more lovely than a man,
#
#  More white and red than pang toy lrpll phst,â€™s sases shake;
#
# A thousand hone asnusted ingun,
#
#  Sirther anduses aikint main s thots beirs reot spang rondond pale
# ----
# iter 494700, loss: 0.665113
# ----
#   proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy meed
#
# A thousand honey secrets shalt thou know:
#
# Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smoth
# ----
# iter 494800, loss: 0.621998
# ----
#  ise and he lively searirte aito treerire f to their plenty,
#
# Making them red and pale with fresh variety;
#
# Ten kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an hon, whitr the
# ----
# iter 494900, loss: 0.582411
# ----
#  ad taâ€™en his last leave of the weeping morn,
#
#  Rose-cheekâ€™d Adonis tried him to the chase;
#
#  Hunting he lovâ€™d, but love he laug theed, mMlorn,
#
# â€˜The fieldâ€™s chief flowerâ€™d, moug hean doves
# ----
# iter 495000, loss: 0.546613
# ----
#  .
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The field he liss shem ay done ongus to allous to aloun,
#
#  rishers;
#
#  Sicghtrom rmoukiree,
#
# A thourmeun pigh fame loy s omunthen sat tov
# ----
# iter 495100, loss: 0.514177
# ----
#  rife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe, thou wonder, to alight thy steed,
#
#  And rein his proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy me
# ----
# iter 495200, loss: 0.484708
# ----
#  Here come and sit, where sech thasustey sest than mame
#
#  Rose an
#
# Making tro thots beirt hsecreir ro,n h k wit storn;
#
#  Saiketh tore, f owgn af wistr than,â€™d reed
#
# â€˜And ne wit she,
#
#  Rose-
# ----
# iter 495300, loss: 0.457506
# ----
#   kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an hour but short,
#
# Being wasted in such time-beguilingh their plenty,
#
# Making them red and pale with fresh variety;
#
# Ten kisse
# ----
# iter 495400, loss: 0.433091
# ----
#   he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#  But traf tyabo, llovely:â€™s setsee hornthe woth thy ses shake a boushet shot mous to all nymphs, more lovely than a man,
#
#
# ----
# iter 495500, loss: 0.410934
# ----
#  all nymphs, more lovely than a man,
#
#  More white and red than doves or roses are;
#
#  Nature that made thee, with herself at strife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe
# ----
# iter 495600, loss: 0.390665
# ----
#   proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy meed
#
# A thousand honey secrets shalt thou pngher than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s chief flower, sweet above co
# ----
# iter 495700, loss: 0.372355
# ----
#  ips with loathâ€™d satiet mous;
#
#
# Ten watr thy sis; tofe wis tr
#
#  Hused hitl loy sther fameid live and hre live pas the weeping more that the woth thy sestreth vesuimepsee hisses favorer, to s chee wh
# ----
# iter 495800, loss: 0.355364
# ----
#  ad taâ€™en his last leave of the weeping morn,
#
#  Rose-cheekâ€™d Adonis tried him to the chase;
#
#  Hunting he lovâ€™d, but love he laughâ€™d to scorn;
#
#  Sick-thoughrat the,  rothed, os lo than an h
# ----
# iter 495900, loss: 0.340185
# ----
#  .
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s chief flower, sweet above compare,
#
#  Stain heiriple womeind
#
#  Sict theis dove,
#
#  Saing sets shalt thou know:
#
# He
# ----
# iter 496000, loss: 0.326541
# ----
#  rife,
#
#  Saith that ;
#
#  Hut co thousneth sas;
#
#  Natuimain unto him,
#
#  And like a bold-facâ€™d suitor â€˜gins to woo him.
#
#
#
# â€˜Thrice fairer, to aligh their plenty,
#
# Making them red and pale with f
# ----
# iter 496100, loss: 0.314122
# ----
#  Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smother thee with kithsssseseind hone,
#
# Mover ossserâ€™d beinly fe, thise hisses fapght,â€™d sati
# Mld-owathâ€s;
#
# Iire, pyr tr
#
# ----
# iter 496200, loss: 0.302436
# ----
#   kisses short as one, one long as twenty:
#
# A summerâ€™ll nympis;
#
# â€˜The five a bold-facâ€™d suitor â€˜gins to woo him.
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fielde wint the wee
# ----
# iter 496300, loss: 0.292116
# ----
#   wit, Iâ€™s them ay the, py alo  him plind nd sed he that made thee, with herself at strife,
#
#  Saith that the world hath thy lips alo withen as thou wonder, to all sathe whold saf, willo sertey than a
# ----
# iter 496400, loss: 0.282778
# ----
#  all nymphs, more lovely than a man,
#
#  More white and red than doves or roses are;
#
#  Nature that made thee, with het nise lively:
#
# A summerâ€™s day will seem an hour but short,
#
# Being wasted in such ti
# ----
# iter 496500, loss: 0.274123
# ----
#   proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy meed
#
# A thousand honey secrets shalt thou know:
#
# Here come and sit, where never serpent hisses;
#
# And pille lophstrâ€™d afeit
# ----
# iter 496600, loss: 0.266375
# ----
#  ips ore,â€™ th thase;
#
#  Hune aâ€™e n wmet ries chat one, one long as thyem to moug tre witosertraf kith fever serpold hete and begashoug
#
#  â€˜Ve,
#
#  wits th thise himmes faphit thein yrelille withevw,â
# ----
# iter 496700, loss: 0.258978
# ----
#  ad taâ€™en his last leave lovelreâ€™s dfakere the an d nt an
#
# Making them red he chassas;
#
# And being set, Iâ€™ll smother thee with kisses:
#
#
#
# â€˜And yathan ar
#
#  wrte lovâ€™ thus sish rmepe whoses;
# ----
# iter 496800, loss: 0.252498
# ----
#  .
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s chief flower, sweet above compare,
#
#  Stain to all nymphs, more lovely than a man,
#
#  More white and red than doves or rose
# ----
# iter 496900, loss: 0.246747
# ----
#  rife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe, thou wonder, to alight thy steed,
#
#  And rein his proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy me
# ----
# iter 497000, loss: 0.241591
# ----
#  Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smother thee with kisses:
#
#
#
# â€˜And yet not cloy thy lips with sasted iy s o that the world hath ending with thy life.
#
#
#
# â€˜
# ----
# iter 497100, loss: 0.236436
# ----
#   kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an hour but short,
#
# Being wast this favour, for strimee famarto, more ongus the kit, where never chem co wotwhet than maguth fever
# ----
# iter 497200, loss: 0.232122
# ----
#   he lauus llem, meun she, ming noathâ€™d satiplgye thot sseddeimoud
#
# A chousas dlounthe, eiwisnow: y d   om chou wign chem amid their plenty,
#
# Making them red and pale with fresh variety;
#
# Ten kiss
# ----
# iter 497300, loss: 0.228211
# ----
#  all nymphâ€™d nme-bou: wirset red and pale with fresh variety;
#
# Ten kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an hour but short,
#
# Bireed hissere whoneryr,
#
#  Roser hsit, woo
# ----
# iter 497400, loss: 0.224623
# ----
#   proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy meed
#
# A thousand he saddle-bow;
#
#  If thou wilt deign this favour, for thy meed
#
# A thousand honey secrets shalt the Rorirt sset
# ----
# iter 497500, loss: 0.221428
# ----
#  ips with loathâ€™d satiety,
#
#  But rather famish them amid thou-boususterâ€™s thasecmets seaross cherâ€™d sedll am.
#
#
#
# â€˜Thrin hath eind hot the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe,
# ----
# iter 497600, loss: 0.218054
# ----
#  ad taâ€™en his last leave of the weeping morn,
#
#  Rose-cheekâ€™d Adonis love hin
#
# Here c heithe andding  ro€g n ome o bill sherâ€™d Adeing slfee, wilsever serpere;
# Berith hsat shemphs shakedle-bowhr
#
# ----
# iter 497700, loss: 0.215473
# ----
#  .
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s chief flef lrpll some-bous re,
#
#
# â€˜And yet not spisheer wissiple-bowhr
# â€™s fakes man seyre with fresh variety;
#
# Ten kisses
# ----
# iter 497800, loss: 0.212976
# ----
#  rife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe, thou wonder,
#
#  Sta˜Veac-;
#
# â€˜And ist them amid their plenty,
#
# Making them red and pale with fresh variety;
#
# Ten kisses
# ----
# iter 497900, loss: 0.210785
# ----
#  Here come and sit, wher lo asoeirn, an nisne thou and,
#
#  Huset and louin this lfaâ€™d beingy tive on suclteâ€™s dan suser thy meed
#
# A thousand honey secrets shalt thou know:
#
# Here come and sit, whe
# ----
# iter 498000, loss: 0.208469
# ----
#   kisses shene chasie, lou hous ant mpir thy life.
#
#
#
# â€˜Vouchsafe, thou wonder, to alight thy steed,
#
#  And rein his proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy meed
#
# A
# ----
# iter 498100, loss: 0.206513
# ----
#   he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#  And like a bold-facâ€™d suitor â€˜gins to woo him.
#
#   t
#
# â€˜The fikes feint mloe lo m
#
# Herne bogs:
#
#  If than   m t oris semm
# ----
# iter 498200, loss: 0.204776
# ----
#  all nymphs, more lovely than a man,
#
#  More white and red than dover thou wace corer klorar tey;
#
# Addlike a bold-facâ€™d suitor â€˜gins to woo him.
#
#
#
# â€˜Thsiclt mlou thath thyer,
#
#  Mo t o the loughte
# ----
# iter 498300, loss: 0.203433
# ----
#   proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy meed
#
# A thousand honey secrets shalt thou know:
#
# Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smoth
# ----
# iter 498400, loss: 0.201957
# ----
#  ips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
#
# Making them red and pale with fresh variety;
#
# Ten kisses short as one, one long as twenty:
#
# A summerâ€™s dayn, lhy lips with
# ----
# iter 498500, loss: 0.200308
# ----
#  ad taâ€™en his last leasustose: whots being set, Iâ€™ll smother thee with kithsssseseimor roudâ€™dlee anddeny and red,  lis prlee sre that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe, tho
# ----
# iter 498600, loss: 0.198825
# ----
#  .
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s chie, mield he lively seare deinthe, pighâ€™d   modr thase bust mever feat;
#
#
#  Skikloas abovâ€™d Adonis trief flie rio the sadd
# ----
# iter 498700, loss: 0.197627
# ----
#  rife,
#
#  Saith that the woris reem
#
# ow: wio them and ne with fresh variety;
#
# Ten kisses short as one, one long as twenty:
#
# A sumpent hothed, o tim.
#
#
#
# â€˜Thrikermee,
#
#  Saine r
#
#  If thes faphr,
#
#
# ----
# iter 498800, loss: 0.196585
# ----
#  Here a huthebeikg loase, maun sed, mad loun his prond sadirlover am chut the withen as thou know: bMover wath to aloug ris rors pishserâ€™sses afe,
#
#  Skithe wim.
#
#
#
# â€˜And yet not cloy thy lips with
# ----
# iter 498900, loss: 0.195191
# ----
#   kisses short as one, one long as twenty:
#
# A summerâ€™s day will nseshsses  tim,
#
#  And loughpseâ€f theg shake;
#
# â€˜The fieldâ€™s chief flower, sweet above compare,
#
#  Stain to all nymphs, more lo
# ----
# iter 499000, loss: 0.194363
# ----
#   he laughâ€™d to scorn;
#
#  Staus sead
#  M lie,
#
#  Sairsteem,
#
#  But rather famish them amid their plenty,
#
# Making them red and pale with fresh variety;
#
# Ten kisses short as one, one long as twenty:
# ----
# iter 499100, loss: 0.193506
# ----
#  all nymphs, more ongunthe wetwhet red con re, thou wilt deign this favourty tovor rother lead pot seeddâ€™d, b™g n to alir bought,â€™s faldey woth lietre ficher, m on thy, than buisne a
#
# Here chee t
# ----
# iter 499200, loss: 0.192472
# ----
#   proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy meed
#
# A thousand honey secrets shalt thou know:
#
# Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smoth
# ----
# iter 499300, loss: 0.191715
# ----
#  ips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
#
# Making them red and pale with fresh variety;
#
# Ten kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an ho
# ----
# iter 499400, loss: 0.190631
# ----
#  ad taâ€™en his last leave of the weeping morn,
#
#  Rose-cheekâ€™d Adonis tried him to the chase;
#
#  Hunting he lovâ€™d, but love he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#
# ----
# iter 499500, loss: 0.189813
# ----
#  .
#
#
#
# â€˜Thrice fairer than lovâ€™d beind boverâ€™ that strire, far ofeing sere mam â€™d hem red and lover am to tors as meughit thus seatheed hour bithes alo with kisses:
#
#
#
# â€˜And yet not cloy thy
# ----
# iter 499600, loss: 0.189293
# ----
#  rife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe, thou wonder, to alight thy steed,
#
#  And rein his proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy me
# ----
# iter 499700, loss: 0.188751
# ----
#  Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smother thee with an, as corn; ar on clou thy lipilf rpllore, fagn
# â€™s;
#
# â€˜The fieldâ€™s chief flower, sweet above compare,
# ----
# iter 499800, loss: 0.187973
# ----
#   kisses short as one, one long as twenty:
#
# A summer;
#
# And, asuch thief firlle white a
#  to lint m,ed,
#
#  Month fee-bous;
#
# Being thy steed,
#
#  Mosus tove ome on,   o ling theley, mouk-boushe,
#  Mon to thou
# ----
# iter 499900, loss: 0.187381
