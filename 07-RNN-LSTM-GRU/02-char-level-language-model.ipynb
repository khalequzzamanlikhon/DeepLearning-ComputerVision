# %% [markdown]
# In this section we will use RNN for a very simple task, which is character level language model. This is a many to many example of RNN.
#
# **WorkFLow**:
#   - feed a sequence of characters into RNN
#   - at every time step we will ask the RNN to predict the next word.
#
# Let's say, we have a training sequence of just one string "hello" and we have a vocabulary $V \in \{\text{"h"}, \text{"e"}, \text{"l"}, \text{"o"}\}$

# %% [markdown]
# ### Work procedure:
#  we know the basic of RNN and its equation from the previous section. Now we will make one hot vector for each corresponding letter in the vocabulary as follows.
#
# ![alt text](images/5.PNG)
#
# Then we will feed into RNN a single vecton at once at a single time step. Initially the $h_0$ is an empty vector of size 3 in this case. Now applying the RNN function with the same weight matrix we get as follows,
#
# $\begin{aligned}
# \begin{bmatrix}0.3 \\ -0.1 \\ 0.9 \end{bmatrix} &= f_W(W_{hh}\begin{bmatrix}0 \\ 0 \\ 0 \end{bmatrix} + W_{xh}\begin{bmatrix}1 \\ 0 \\ 0 \\ 0 \end{bmatrix}) \ \ \ \ &(1) \\
# \begin{bmatrix}1.0 \\ 0.3 \\ 0.1 \end{bmatrix} &= f_W(W_{hh}\begin{bmatrix}0.3 \\ -0.1 \\ 0.9 \end{bmatrix} + W_{xh}\begin{bmatrix}0 \\ 1 \\ 0 \\ 0 \end{bmatrix}) \ \ \ \ &(2) \\
# \begin{bmatrix}0.1 \\ -0.5 \\ -0.3 \end{bmatrix} &= f_W(W_{hh}\begin{bmatrix}1.0 \\ 0.3 \\ 0.1 \end{bmatrix} + W_{xh}\begin{bmatrix}0 \\ 0 \\ 1 \\ 0 \end{bmatrix}) \ \ \ \ &(3) \\
# \begin{bmatrix}-0.3 \\ 0.9 \\ 0.7 \end{bmatrix} &= f_W(W_{hh}\begin{bmatrix}0.1 \\ -0.5 \\ -0.3 \end{bmatrix} + W_{xh}\begin{bmatrix}0 \\ 0 \\ 1 \\ 0 \end{bmatrix}) \ \ \ \ &(4)
# \end{aligned}$
#
# ![alt text](images/cg6.PNG)

# %% [markdown]
# **Embedding layer**: It is a layer that converts categorical data, words or characters into dense vectors of real numbers. This process of representing categorical datat as continuous vectors is known as embedding. To convert a one hot vector into embedding layer we need to take an embedding matrix and then perfrom matrix multiplication between this matrix and the one hot vector.

# %% [markdown]
# We can also predict the next character at each timestep. Since there are 4 characters in the vocabulary, predicted vector at each time step is 4 dimensional.
#
# ![alt text](images/6.PNG)
#
# At first we fed "h" in the network. RNN predicts next charcter at this time step with current settings of weights as,
# $\begin{bmatrix}1.0 \\ 2.2 \\ -3.0 \\ 4.1 \end{bmatrix} \rightarrow \begin{bmatrix}\text{"h"} \\ \text{"e"} \\ \text{"l"}\\ \text{"o"} \end{bmatrix}$

# %% [markdown]
# Here, the scores refers to the corresponding characters in the vocabulary. For example 1.0 for "h" and so on. But the prediction of each time step will be the character corresponding to the highest score. In this case highest score value is 4.1 which refers to "0". That means at this time step we don't get our predicted "e" which refers to wrong prediction and high loss as well.

# %% [markdown]
# At test time, we will feed one character(prefix) to the RNN and get a sample for that time step. We will put this sample to the next time step. We use sample for the next time step is actually a benifit becuase by doing so the the model can diversify.
#
# **Q** Why do we use one hot as input instead of softmax vector at test time?
#
# **Ans**: Because the model is trained with one hot vector. Therefore if it sees other than this then it may fail to give correct output. Moreover, in practical the input may be too large. For example, if we generater word instead of character then the vocabulary contains any word in english dictionary. This is computationally really bad.
#
# ![alt text](images/7.PNG)

# %% [markdown]
# ### Backpropagation and Gradient calculation
# In this process of RNN forward propagation is kind of forward through time and backward propagation is backward through time. Therefore if the example is too large such as one whole wikipedia article then for all the words in forward pass and then calculating gradients for all the words and updating the gradient is not practical. Because it will take long in fact model will not converge. Therfore we will calculate loss only after a certain number of steps say 100 and so on. By doing so the forward pass and all the hidden time step remains the same but the backward pass and gradient calculations become easier because we only calculate gradients over the stepped loss. we call this method **Truncated Backpropagation** through time.
#
# ![alt text](images/9.PNG) ![alt text](images/8.PNG)

# %% [markdown]
# ### Gradient flow for vanilla RNN
#
# We already know, RNN takes previous hidden state $h_{t-1}$ and input $x_t$ at any time step t, and pass the calculated result through tanh, $h_t = tanh(W_{hh}h_{t-1} + W_{xh}x_t)$.
# For backpropagation we need to find out how the last time step affects the weights of the first time step $W_{hh}$
#
# **calculating gradients**:
# The partial derivative of $h_t$ w.r.t. $h_{t-1}$ is, $\frac{\partial h_t}{\partial h_{t-1}} =  tanh^{'}(W_{hh}h_{t-1} + W_{xh}x_t)W_{hh}$
#
# We update $W_{hh}$ by getting derivative of loss at last time step w.r.t. $W_{hh}$.
#
# $\begin{aligned}
# \frac{\partial L_{t}}{\partial W_{hh}} = \frac{\partial L_{t}}{\partial h_{t}} \frac{\partial h_{t}}{\partial h_{t-1} } \dots \frac{\partial h_{1}}{\partial W_{hh}} \\
# = \frac{\partial L_{t}}{\partial h_{t}}(\prod_{t=2}^{T} \frac{\partial h_{t}}{\partial  h_{t-1}})\frac{\partial h_{1}}{\partial W_{hh}} \\
# = \frac{\partial L_{t}}{\partial h_{t}}(\prod_{t=2}^{T}  tanh^{'}(W_{hh}h_{t-1} + W_{xh}x_t)W_{hh}^{T-1})\frac{\partial h_{1}}{\partial W_{hh}} \\
# \end{aligned}$

# %% [markdown]
# Now it's time to apply all these theory into code. Here I will use the code which was written by **Karpathy** and will analyse the code.
#
# Code link: https://gist.github.com/karpathy/d4dee566867f8291f086

# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
# Out:
# '\nMinimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)\nBSD License\n'

# %%
import numpy as np
# data I/O
data = open('data/Venus_and_Adonis.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print ('data has %d characters, %d unique.' % (data_size, vocab_size))
# Out:
# data has 1136 characters, 43 unique.

# %%
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# %% [markdown]
# These dictionaries are created to map characters to their corresponding integer indices and vice versa. These dictionaries are useful when particulary working with text datas.

# %%
# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# %%
# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %% [markdown]
# Here, dhnext is initialized to present the gradient of the hidden state that is passed from one time step to the previous time step during backpropagation through time. By initializing with zeros it means that no accumulated gradient from the previous sequence, ensuring that it doesn't carry over information from the previous sequence to current one.

# %%
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %% [markdown]
# - this function generates a sequence of integers from a trained RNN language model. It takes an initial memory state "h", a seed character index "seed_ix" to start generation, and the desired sequence length "n".
# - x is used to represent the one hot encodeing of the current character
# - ixes: to store generated character indices.
# - ix = np.random.choice(range(vocab_size), p=p.ravel()): Sample the next character index (ix) from the probability distribution p. This is done using np.random.choice, which selects an index from range(vocab_size) with the probabilities defined by p.
# - ravel():flattens the 2d probability distribution.
# - x[ix] = 1: Set the element in x at index ix to 1, encoding the character that was selected as the next character in the sequence.

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

# %% [markdown]
# - 1/vocab_size: probaility of guessing a character from the vocabulary.
# - multiplied by  sequ_length: to scale the value based on the seq length

# %%
while True:

  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]
  
  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter 
  if n==500000:
    break
# Out:
# ----
#  Bfg˜,s:m fwsBm  Tdpiadg:pg€â.t.As€efââ
# ukrVwpB,n;
# ;IRTbamrBBvnsoâw TIINrvguAusMfN:˜nvtpRMN,
# wdoBe™
# htVBV,
# b.,NBkHiaSâsd˜ugn™™;N˜n;,hoTrpAskvwV™âyydV gTB:RIw,™T.THN.˜˜™ueptTin:ei
# hâ-ivlIRdn g,sk™o:k;HV
# ----
# iter 0, loss: 94.030005
# ----
#  iHâohe
# mh bu
#    ArhVst ahuguc  f ;nuut tm oobk m
# nlgnn
# sh˜ enâ tdodeoh ˜uâgn
#   mgse™ €et aihhr maodo
# d atueoy™ediinorenmmoeshe l itgs rt˜  w htreodu, msbmnoltkeoy  sm
# mAanglscyaot,  stib;,
# ti  €. l  a
# ----
# iter 100, loss: 94.452962
# ----
#   e l g aas, sAeeeawmeia  oasrrimerhf€tdsl omrderwieo
# ,ac
# h
#   mhrd
# fsa; or
# nt
# c cmve,eaahti€tyd
#  rieenl asee hmm;
#   aeee craebe
# e  dfnithsf eeh tbemon bh™ hyin p feeohliwmeo
# fwhoelr
# kAd Ts rh
# ˜ Ae ât m
# ----
# iter 200, loss: 93.329062
# ----
#   ,rihycasah ose rhyhr laliosetu ghdalo rthlmochi
# i ee
# ,o ,oâ˜ismetuggn
# n
# h nh tiA i
# isrtâN˜u naao  mhatit ,, on kenhmwhegiirheuo uoahyr
# aoo onuo s Bs smrhdt,rsheiy eohi o
# t˜s sI, s thfw
#   h t Vseair
# ----
# iter 300, loss: 91.782779
# ----
#
# rhm vaeTe t t ,gd e
# ms MhitorS th  fa;iloache w;y nâcinand
# tae
#  ch
# ,y yhhm  hilhog- em Mreaac
# a;t tpamhtnuki
# lf
# u s tftre dat t rrde g oairndhoitenaatin:t th  pa
# € evan gnbdhs t
# €Ha k dinggr athowa
# ----
# iter 400, loss: 89.943076
# ----
#  d thei,€™eib a; ker ,e kfn,ga, bo epk ntith˜™eo tibopbk™loyesesnm hiawf wennItd deveinoe sae seIfHT leeifgfl l dhcisee mtyd rheen Ave,ndMthlin
# mpweg
# a toe
#
#  ˜d rem :wit rdfettaneetndefthimose sonItye
# ----
# iter 500, loss: 87.864724
# ----
#  nis wad y her thrwmat thisr rif led Iilforoi
# iTh
#
# g wiwo™ onN y  sman te
#
#  S wol l beee tcren whf,e twmatem t eSoe  come. the f
#  pire
#
#  ths usdlra asaw; em tathe whchaamre feic meSl
#  ce-lhulin f oe h
# ----
# iter 600, loss: 85.613338
# ----
#  re wree math,i, dithond n th airol l,bh nei: di˜shat thya tithokaeheo
#
#  l,t
#
#  Rhap heind k Sn con h pafe tisthtua€V:
#
#
#  woi
#
#  And i thos silNa
# cleâ€™de™r ch ty are, le tno
#
#  atoeeith they s
#
# To leâ€™
# ----
# iter 700, loss: 83.179211
# ----
#  ithy™ thsumsathomr tho toathsiedthe, lt nrt th dat,g So thoredth  Aothe,t wou fes nid se, eat shet lâNtoty wttornthidere s shasdthru
#  tn,prm, wou ta
# , we walsthe wn w
#
#  Hh sai
#  a; st ta thde  hithed
# ----
# iter 800, loss: 80.731502
# ----
#   t theyng le,T
#  avo ty i
# rd w thof thong forese sege f to t, nd, ar sheth, we,is:wetâ€™T â€Rdd Sal,g  aird
#  g uth c fees ee:thend
#   te-altdheet ne
#   fn,
#
#
#  ng iand B thes;
#
# Te;
# M g,ere ton-Aodeg ho
# ----
# iter 900, loss: 78.287742
# ----
#  lg, €™sorthomeg,,â™d yorâ€-,n liir sed sesemilim
#
#
#
#  d keeveg,
#  no,,
#
# Bd chand the-tif;le thy n thvem fol,
#
#
# , wo-d  move,yd
#
#  Rhd-tait ed he .
#    wi
# i bmacoyeu
# w,
#
#
# â€˜Hfle whmhoodisund t m t  hemS
# ----
# iter 1000, loss: 75.891933
# ----
#  ut chin;
#
#  Aeis fed
#
#
# ˜HVom So we dilitng sokeâRs rin whms˜oud
#
# €Vshe d aben aet of hed suntin,
# n-; ibathe, wamyferld fis di ooae a
#
#  he, mad inale, houchâ€™bed wimtuo mau nindh tves biusme-n shaufrh
# ----
# iter 1100, loss: 73.510711
# ----
#  Ased hoiunthug sed Aein,
# €Retf witld th theseg friined s chees foulenA
#
# S™e bh to kas  derises,
#
# s shaly sean, chy susatule  ese , eiripl li vaTh lou lis elgn n r,yg e,. sa,
#
# €˜Aneâ€™ ho-waned seif th
# ----
# iter 1200, loss: 71.154728
# ----
#
#
#
#
# n thy taveud lif wia
#
# ng ;
#
#  n ammin  alhsh thor thof n che  oois  ao sathares,oid .rerlind Bss thri mtrein, shathethal, wed
#
#  Sd aine wan f thprin-thvami soachedg ant  kainserty  s wit fathsssre
# ----
# iter 1300, loss: 68.948334
# ----
#    ond
#
#  Hase th boe toee, se
#
#   lo  t aut
#
#  Hane,  beemSink. thesming ve tiewovt tunt tonthed areosug mose;
#
# Temwkis wh ale bripohe thed an thleingved tnan doale;
# ngâ€™d, h
# kisew he the t, hhy sive l
# ----
# iter 1400, loss: 66.696970
# ----
#  chutem,
#
#
# €˜Ind n, wy twirh chot-: re thee win,
#
# Athor sher feet un tho,tw tosind thmeâ€™d sd-theteugfeo  thet ar fv-thes
#
#  we
#
#
#  €un
# r woset€g byaswhe-wolf thouns theesevomIakeme wigorrnd rivt thy t
# ----
# iter 1500, loss: 64.524064
# ----
#  tavacitr  tot, beven;
#
# gâ€™ asas,
#
#  Anr oe sns thous se hoe tondâ€˜. sent au fra litoy he tues masit, thilg sara thor f leoleghinphafle-c
#
#  phes al  rreug simaseithin twoud towid,
#
#  Beit,  ;ekd filht
# ----
# iter 1600, loss: 62.443369
# ----
#  €.n sed, mosclond ahed see an hiur femleed achereswes arwesserseslo tha-wuis rtt liares fwiat ari
# nonrh:t ra w t thf ste he Ind,
#
#  Ir ci
#
#
# ,   u wanger free-s enet thi
#
#  hhourt san s,ed ae anere rorâ€
# ----
# iter 1700, loss: 60.387232
# ----
#  faoeadee
#  Saindn:
#  doIhar s;
#
#
# ng amrsys ve sheet sn thesech tapaut th swe-mwin, co seth kitngwem,
# MI
#
#
# A calegNal:s:swhet
#
#  coveubSotyd homafe wey,
#  €ygu fre ca hey,
#
# â€™sat losp
#
#
#
# Bee theth smatle
# ----
# iter 1800, loss: 58.480980
# ----
#  eeas amech:
#  Beo,  hii uiwingyukaHs misulthas momethivakile;
#   or with sut eref d oiches huy lomwer tn tier bos sunthilasnl ant,  lashls maohee;won,
#
#  hine,
#
#  Hnwe,  a
#
#
#  hisemy fath toybmour essegg k
# ----
# iter 1900, loss: 56.554878
# ----
#  y lilr the, heat, bomer  had yet
#
# Ten t
#  th toy hid rere smred halsef anesg mort; sethakbeane with
#
#  Mahwond seus thougevd lonte fwivt riei seoind nnd che.
#
# M sharol, Iid we le kimp
#  w cheing Ikouch
# ----
# iter 2000, loss: 54.667926
# ----
#  A bw dt t and headadn slitsmed,  aoussimpalt maauon kith le-Vinâbise tughin wilt, fart yee and wore wind rt lithad en lite np€˜gerle,
#
#  wout he-Htare, €. laulimey with le.  heichede Vee lishtd
#
#   sath
# ----
# iter 2100, loss: 52.997761
# ----
#   him mt samre,
#  Voattyg, toi loty
#
# â€˜T vakis foit su o w ocetu bose y walt taan yomain baeit Vound Mort s oupf fâ€˜An; wit  aauâ€™dan, hither
#
#
#  Tied t  wot, €n.H th;chet y chegy;
#
# Ten:
#
# athind;
#
# ----
# iter 2200, loss: 51.212946
# ----
#  -cheelt aseed love thy eis, bed loud thy cadesunt s, rerâ€™s tey,
#
#  And, sâ€™ers, Vere hn toieiwisy thth thee, An hy  wad s thaleen ain wo-thee himes hou fer love-bild fore an  o ling hee,
#
# â€˜Angto;
# ----
# iter 2300, loss: 49.420862
# ----
#  se, aou cithos meimh to perlingâ€˜Thifrengy tho then,
#
# Bet s  tor wauwi kâ€-thnâ€˜f:un, ce lits waâ€™em
#
#  hoved s mat tom.   aoret s mach f miacod shafeâ€˜sum, y wareâ€™s tteg
#   t
#
#
#
#  preg olor thee
# ----
# iter 2400, loss: 47.932077
# ----
#  eg  aing thi
#
#  Anin. asefenkh thore fhet, swer to pare pomgathrkeshivlos arsdeighe toe woity thd thimae, bud tosem free,
#
#  €™ tiru wilm ther sato thoror lintyrere,
#  Saldhomathploty homelosser, hiat, s
# ----
# iter 2500, loss: 46.633955
# ----
#  ithes
#
#  r,â€˜Ang oese,pant ho tore-A werkips wharegud
# H anth:, heeg heeBugenth theeâ€˜herm s lo shart to hoy seer Husa
#
# Hân™ urwey hi
#
#
#
#
#
#  Slone thit macies yein and
#
# Bâ€™ded acle ho wocâ€™de f t
# ----
# iter 2600, loss: 45.005935
# ----
#  ad taaligu kit
#
# kâ€˜Vodan auiching arig sed
#
#  Sain. andt suther with:
#
#   matt hedwle, kis,at
#
#  Soree  heines, feer y what
#
#
# âR. le,
#
# Mekl dgm th t
#
#
# ng math:
#
# A ver toe wacheâ€™d ve wilg, seici w-sr
# ----
# iter 2700, loss: 43.405816
# ----
#  wh ang
#
#  s,t
#
#   -ned niThen;
#  And surs sroferl sheitonwhrug wamr t
#  Sermlde
#
#
# B tien li soutn wety nee,n, kees sle phimaty
#
# â€˜Thn tha l ath th r ng
#
#  Rine, thee-Snes on thet abols  a athendhislifet
# ----
# iter 2800, loss: 41.920954
# ----
#   dat ve and seed, lovely
#
# A Sare lo todeygurh them to t
# €˜And veren h m math awath omer gnerâ€™e shit
#
#  Sore â€ meven aver  aichit theili lis shl staindâ€™th Hiai
#
#
#  Aer s em t peoan sath
#
# Ten ch do
# ----
# iter 2900, loss: 40.487297
# ----
#  : bo elsumaee
#
# .
#
# A
#
#
#
#
# T. aig boath. aon,
#  NaAs thpely erd se aund
# r withokise-boud nee,  mnees se™d world hach sashor swee,
#
#
#  Saith thith thas th to and:
#
#  Iw: wodel ato dor af shorerf,â€™âTenf
#
#
# ----
# iter 3000, loss: 38.978260
# ----
#  bto thed â€™ert seaty,
#  -cafeeaf merfet, Nacotn s sey as see
#
#  And to roseve thdilg k™ston to treet ar the; wimnghifler th th ahous ththm awoersedm
#
#
#
# Teny hi
# €˜guner m ifenf,  feu
#
# âM™dn arese ch
# ----
# iter 3100, loss: 37.512077
# ----
#  y soond ; fred
#
#  Basmywim˜s th-liru:
# â€˜€™d ho litneInt lovee hun withe hir ther
#
#  Sond rhie whoun  houndâ€˜gwer anewadren; ;om lthe, wo
#
#  Ae th load licheifouf samyent,
#
# Being ald bostat nmare both
# ----
# iter 3200, loss: 36.185474
# ----
#  bnt: hom phees, chere tim.
#   re thiuls an wiru fresaseeIo tui tore,f oreke to h deieparesen.
#
#
#
#   aad
#
#  Rin,  remwilisath twee f eisty hid paoi
#
#  sn pisteis shomahe ei tho
#
#  Stain, su
#
#  Seaf toov l
# ----
# iter 3300, loss: 34.925295
# ----
#  e wo parr shlan-s na
#
# , And reilale sa
#
#
#  line  merremwen hou wimwin eishy lin, hocwysy heree   oareet aid le-bedâ€˜. ar rrithâ€™e ;
#
# € ;
#
# g withy lifthir, whee,
#
#
#  Sains  cedatâ€™lb thaththan anld th
# ----
# iter 3400, loss: 33.649176
# ----
#  issrrf thminds ree, wo yil, hhate.  aree, trileed hartd serl wiaer s arâ€™semo
#  stou toreed seole sere tharo wore aon;at  thee; wire tharo,
#
#
#  Ansther
#
#
#   sito the, o and ser, where semptles limey,
#
# A
# ----
# iter 3500, loss: 32.311727
# ----
#  ad ta-theve bt theine wathd being bumashiâ€™dnAs n ft-pangâ€™ng wast ane, y anid mt sherthalane lo Noul â
#
# A Rn;
#
# And taru w thevâ€™d, SathiloAchs maslâ€™s shmwaslerpand wied-Ten an ano
#
#   need toert
# ----
# iter 3600, loss: 31.695316
# ----
#  .
#
#  shety y masfore-sind
#
#  Hrem an saktliwith une ht tasuafed thoree sikk, ses in,
#
# Ad sithan on tires tore; hir than  li;s moregs se-chret, ssrfet of ther wimiswitos ne
# u
# n hies the, hese leat linek
# ----
# iter 3700, loss: 30.758246
# ----
#  ain,
#
#  Natuis,
#
# Han, urie, fathomany.h an an lidsmand rm;
# S,
#
#  Anokr h  ered hathd to the sytind and honty sers thawo toyghith f the wort an ant aiestouse, wit Samonthe
#
# €M chost eo hissyund femparege
# ----
# iter 3800, loss: 29.630066
# ----
#  Here-thiloud lamd ltymaking shthree
#  wott won dive sesyshtd hoe dove fe;
#
# , Butwive wath thy feith thy,
#
# â€˜An,
#
#  And re shad nyplound:
#
# Ming y thoadeng bet yer sy:whafiles athore hise, werl stathan
# ----
# iter 3900, loss: 28.517816
# ----
#   arod tuch cheing thoud lote-boy: loan, sat, m leeth mouus fare toeeyend toee  non ang theu ail lilt toarâ€™lastonptreâ€™d to c sh.gee sumbemy:f d ce wimwâbpaund tis, Vere louchow; as tiithe.M as ored
# ----
# iter 4000, loss: 27.376614
# ----
#  m s matu homalo aucher set, asein cwelto Ifd wad thy them aostunâ€™ thigulfes mos wot  heer serwilte wialonet re are swint wiur ssee thy wasn ant câ€™d like arieAd sim.
#
#  A vent Mian thoth ssetu with
# ----
# iter 4100, loss: 26.244851
# ----
#  len; romres wore hint, hosesthind,o
#
# €B;, And  mole thrud and peie, d re thot too thovich wond tn hithus marissseenthyesyld dim.
# ps toughâ€™d th beif, shyis â€˜thnâMhserfing hos thonâ€™ensâ€˜ m
#
# Heng
# ----
# iter 4200, loss: 27.557475
# ----
#  ngu linm thy, bore lomet
#
#  Sthose,  red to tend valo self thed p seitaich thoud okes saâ€B thond and re po d oo sasret r oing wove boafd to ld he liple withy sas m-t souphith th tom theugheitoâ€™ tom
# ----
# iter 4300, loss: 30.240335
# ----
#  ed anog yes m cied t ari sho kemsthct
#
#  h-cepige lidte: Bet thore shy aaovess seegricâ€™l sher  her, wâ€™d lrn,
#   theed an amed rid wilR reld than,  moo widn  winl nd ser syee thilithte s  ret bee wil
# ----
# iter 4400, loss: 33.334045
# ----
#  ad Ii tiywipt thed he-kr winton t sate thafoyd freng citâ€€˜Bekip; leef afe thes siet pond thed wity heey this pongind
#
# Bes chd shed hois ng
#
#
#
#
#
# â€˜Nferng bosuibyog maki wastr l€g dart to thive
#  womv
# ----
# iter 4500, loss: 35.458690
# ----
#  im, homi
#
# â€˜Bngwher afe thintâ€™dhin dise lark, lo bucâ€™ won  aeakiAt ave wisare;
#
# â€™s sein witie, ;
#
# ,r :
# â
# n˜
#
#  And save-â€˜Thokf suin thind ak dholt lims wimc tinves tuAu;
#
#
# g ltoveind lis paind
# ----
# iter 4600, loss: 37.367255
# ----
#  ovevd reisee toooin, d:
#
#  Makiskdernt ato  woren, thas woâ€™d thy the paoaritâonâ€™shan wasaltMito ce e ghorrseptore s seg kid t  age dame afan yit samaligre  f ore s wane, â€™,â€™y heve smafae satt :
# ----
# iter 4700, loss: 39.587803
# ----
#  M€˜Ane,
#
# An;
#
#  Rocr thaferunt suam  he cith ti
#
#
# And boun lailoulest
#
#   ad te-ben fadeo liste  h d to l ly ser sasaserasey,
#
#
#
# â€™d
# â€˜VNa
#
# vd-bet edi
# €™; long sasemy to thin that sirek, thiseg  he t
# ----
# iter 4800, loss: 40.953509
# ----
#  g te-bou,
#
#
# HNake;
#
# â€˜Hant uo se, wos  t done;
#
# €Ant yey lore fhin  hored wobegare withe sum,
#
# HAne chef thcn:
# r
#
# â€™d bomd and-bety,
#
# pa-fass withithith st
#
#  Voud so ate vet sicâ€™c tis pone anop
# ----
# iter 4900, loss: 41.703740
# ----
#  ,
#   ndth sede line feibe,r
#
#
# And beregles wasat haat thiwv to  ou  oue motrist ouveyedaleor-pwistwaet :
#
#  Snd hes thamy t oung: tirisp hith m  hempe
#
#   hesweny,
#
#  tom
#
# â€™d Vike whkâ€™sus oigeer mo
#
# ----
# iter 5000, loss: 42.096841
# ----
#  co theis, bu
#   uue,
#
#  Antan ss  a
#  buThimale-pasbirld lmunt
#
#  Hn; lowh  as iwirn,
# T ters oivk sum theeo
#
#  Butt an tharâ€™ee.  min thipldnow˜ tie sery thalir th enekâ€™d cond surn;
#
#  Rotheiwh sasreed o
# ----
# iter 5100, loss: 42.249665
# ----
#   saofet,y;
#  Rossed le deg salmkaseg toou tore himato  to ve fer, Houd omem,
#   thes the, auth woritw: reamore an ore wimwir, bre wot And ming r lirt ait mun tre se. fee anishe pire foum tor wesregunt,
# ----
# iter 5200, loss: 42.121913
# ----
#  as, a t thint and res ser sertoug surssegate-b re,
#  Soveng thytt
#
#
# B;
#
# â€˜Thyss;
#
# Be r thy  hyild h th thimoo  aking sewcore;
#
#   hemvâ€™s terle ho satd thoreg thlthirgofe aloud rr twond beterssampen
# ----
# iter 5300, loss: 41.900430
# ----
#  ar tadimeer than thes tie, u  limind
#
# â€˜In;
# T Asdimematy long tae;And boree, rr thove-byhtuy lis, plis love wimpenes t daar se alaste,
#
#  Iund this
#
# â€™d vamsas loâ€™ssman shoo saslhthesâ€™gndslimest
# ----
# iter 5400, loss: 41.561191
# ----
#  uca-b wiri thas t dangy,
#    akd kifs wisuro bu€ sty theen, mhes, ce wo-bus safldlpegs  asemlIim,
#
#  Ant mo
#
# A suthemoved tied Vint An kid risan an; yefadege-gret Vys to lind vempn scipsuche corse w
#
#  A
# ----
# iter 5500, loss: 41.095168
# ----
#   mong hithed hout  ,
#
# â€™d tore,
#
# â€˜And
#
#  Store woth thar ur inof fo challobeus theed Vore, sheegm y shine,   seise,
#
#   udhle.
#
#
# A  not wo shor dateiped, A
#
#
#
#
#
# Being teot shseiphify l ses lre,
#
#
# ----
# iter 5600, loss: 40.585915
# ----
#   waou ktud tome, an withe hey wid lovel su wleghâ
# B afe shon shoeern s lamp senpand chere;
#
#
#   mor the; hout, â€˜ge choned wist saicind that  arerwâ€™dhe thor ty:l
#
#  Moo  horedâ€˜Moven,
#
#  Nade-fave f
# ----
# iter 5700, loss: 39.968170
# ----
#  d an wicle torer sas tath t natlyslesâ€™e, hâ€˜k: rnes ho lfers an aaitht,
#
#  Mrus tiâ€˜Ved s doud th:
#
# An; wi
#
#  So the coam,
#
# H˜TimVine fuves,
#
# A be shthy wooreo  he, himafs scor thre lontyyfsret  aam
# ----
# iter 5800, loss: 39.313778
# ----
#  dtreis  aamide witl anthin sult n crreg sute ssad orent mun Haredere wire.
#
#  Bnon iinty,
#
# Thâ€™st aaeet
#
# €A beie dre te lashthed pder, wo ftas fe poveg,â€˜The lokpsld one dov houâ€™s clther tior thet
# ----
# iter 5900, loss: 38.637651
# ----
#  her thekâ€˜Ve-bu
#  And him:
#   oree,
#
# â€˜Mint tid to
#  f Voove, lte-chythalisaâ€˜™: scor th sm:le bhafpan lainis toand hith t alo tore fhalishen ais do arthame t as heist rhith te lore limas:
#
# Meng
#
# Th
# ----
# iter 6000, loss: 37.965005
# ----
#  t taet, f
#
#  Bucad thfim:
#
#   hith t tal
#  bouthy wed hafevelâ€™d,
#
#  Norses trer ted chmey artedon su
#   hat th that, mofeos an sur surwente Ify shern,
#
# kâ€˜s, soo makimpond to ser. aiâ€™d An surm lf t th
# ----
# iter 6100, loss: 37.224503
# ----
#  ind
#
#  Romefltwâ€™ ket, thim.
#
#
#
#
#
# B
#
#   mor thy le-flissshond wely  ake  wad.
#   omind feud vepisuâ€™d fame-b.o trerned,
#
#   Ion ft roud hou; y theepave fakimt, And aers
#
# A thath a
#
#  Samiss th endir
# ----
# iter 6200, loss: 36.462220
# ----
#  ut tt to the,â€™shmo tho ee wilgsaf lint dity,
#
#  Inghme-bes,
#
# HNakt,
#
#  kn;
#
#  And te limfd,
#    man, wimad
#
# Mâ€™d yake
#
# A  a
#
# Hfamigaset dhe, to chelT thd vy lipl.
#  And hatl with te hon
#
# MR˜ale cem c
# ----
# iter 6300, loss: 35.699216
# ----
#  hald le,ng  hos to,
#
#   Nairseto did beugengud labicâ€™be ant rere-kiss hime dorege beisups thise,
#
#  M€™eâ€T unt,   mo and were love ysted te sheme win cyafto with to ches thees,tu: ht hat ch athano
# ----
# iter 6400, loss: 34.973996
# ----
#  orcâ€™dâ€™d thith fe f co  flaseps ketuth bnthe-vedydire lou houthyinoy sre;
#
# Besuseaf alon,
#
# HN€˜falt ti se-pantount c
#
# Tend-be f tad bo  fris lt
#
#
#
#  Ander Nade,
# y ches pied houâ€˜gheu thomade chin
# ----
# iter 6500, loss: 34.244420
# ----
#   the ted mo dim eris shou mai  end hath thres s ed de;
#
# Ant vart thee
#
#   hict hin  peith moce kisu thee tore,   ored lo  ovely t tom red rield veist,erâ€™s thun, to therm and meer sald ho nsman thym
# ----
# iter 6600, loss: 33.452299
# ----
#  ™ind ho  de aato â€™ suvâ€˜gang y thy lin,
#
#  Inol losu tor-cle hon tail seâ€™lVst owe-.  thes liâ€˜Th thy thee heith,â€™ kiss;ld thts thyer, thety;
#
# TN˜y, hirs, s ple-lind milis, thee ani fee anony sa
# ----
# iter 6700, loss: 32.765270
# ----
#  -ciAn sith toe pals futhâ€™, shar do epang amae fatler Anow: tha
#
# NSamwingn:
#   hreo thanoh an sim.
#
#   doiâ€˜Thrnd onderseus
#
# MSas atost afate cabedâ€™s ti-t uigo the love-b˜kmthes an surâ€™ see the w
# ----
# iter 6800, loss: 32.055993
# ----
#  nos ti tud mipalt thee lin,
#
#  toe lakiathyin, seeme-weisemfld-fave wieisuâ€™des y the lirit paas lthe  an  rlowiclâ€™ansche.
# â€™aug
#
#  Sisuth chamn;
#
#  Anonder to as  orde to alin, tore thompaoug saf
# ----
# iter 6900, loss: 31.342560
# ----
#  fersse,
#
#  And hath ermhawit
#
#
# HNturt thou hored fafretey, bis lr:r co worevely teim m,
#
# â€˜And veas kato alismed  lisushitat suse-ch thises; this red,
#   toor ty:
#
# Mâ€˜And Marat mat a
#
#  Ro the win,
#
# ----
# iter 7000, loss: 30.562857
# ----
#  o heety;
#
# Ain,
#
#  Saith woou woatins witu ered he lovâ€™d Anipanl hovâ€™d Andaseem:
#
#
#
# IAnd fo, pie  ore, ther.
#
#  sut  tor te, tâ€™d â
#
# Mand y tw:
#
#   her th toe sack;
#
# â€˜Vesu tâ€ge,   orer, u aatishâ
# ----
# iter 7100, loss: 29.810452
# ----
#  ed cad Ivadâ€™g teaty sor thy ferve thalees paab he vove citlâ€™d torent, volalirhuche hers wld peiping to an aven,â€˜Tirint mive to dldpnlg:
#
#  ato câ€™ aiceshonghate lonf aieens an kre,
#
#  Saitl th
# ----
# iter 7200, loss: 29.116528
# ----
#  e seowe thy pnowhils ciee anot, bolove, uny ling Vimumwafnow the wins arer thsaild timee,  houen woor thicâ€™d rmeld Aet famafin to kis,
#
#
#
#   ouegâ€™s lbagut ciche fe ld thend Venty,â€™, theis, whan,
# ----
# iter 7300, loss: 28.465965
# ----
#  er tale bhsove thouâ€˜Voud tad cemafeigh:
#  en;
#
#  Sang nd lo. Sthares fhe-liseti
# f loug lâ€™sus hhoug to aim  at alo terup, oug stern t eile sirtmy,
#
#   he,  h ald tyelemyed cemum, mam
#
# A  hers lter
# ----
# iter 7400, loss: 27.798331
# ----
#  Hame warld ad thos afelf pailfangcâ€™do thyelf,â€™ mosenefris shhedâ€™d bit, mbit, hield ches sad;l sere to thad hetHand himeowive houg lind hethoweo dace corlemcy lond wity and to an kithend falo hin
# ----
# iter 7500, loss: 27.031601
# ----
#  ty;
#
# A the co oo thes thad an,
#
# ™e taer ton amipses sand houâ€˜Thrn ame, dheeu
#
#  ;
#
#   o efer the,  are ties t
#
#
#  Hou with thy s sit, whend Venth:
#
# Bssen l€™, oh shalt at suas sheety t mind ho snt, hor
# ----
# iter 7600, loss: 26.351681
# ----
#   hemd too wimarr the se llcâ€™d morreptoHsund as râ€™digist mon
#
#  Samas thy ldâ€˜Vinsand
#
#
# iBnaks shar then piselpsevapitk thell câ€˜ding naligh theif seam an wot mathe thef smak:  mater to thavâ€™d
# ----
# iter 7700, loss: 25.765161
# ----
#  weo bot an anouin, uito hgas minet, ki;
#
#  And ritl fatirwinngamafret y sure, Saito kige withey lfy sho thougn sou hle-c€˜™d pisesain smdasilf suiet falm ater doughlases
#
# â€™s chislofe fosepang mofpen
# ----
# iter 7800, loss: 25.135607
# ----
#  hend lis, thes the love fhes ligs tede-boud
#
#
#
# â€˜Voug o t en uico po eiphsulf hind to thouâ€˜Voulen, bid lyphemafe loweell te;
#
#
# MMakend the thees,
#
#   ithe shad re theur thmashles s,ouche twerc
# ----
# iter 7900, loss: 24.489751
# ----
#  â€™d,â€˜Arenta
#
#  Sacâ€™d hou the the s arâ€™d te the shad â€™ to t emyrnghhld to waed fae
#
#  S ailin
#
# A talder th lo erie see lovely:  med eee fake
#
#
# Bâ€™d tre-b wigl af the wiel se, shoru;
#  Adane
# ----
# iter 8000, loss: 23.804259
# ----
#  ad thin kri;
#
# BNatuns thortey, himend, ani seiphsesen,
#
#  Mading ther  armterpe tor thort,
# A bmough the cite, eit smymee s hald therâ€™s tadur thy sarmaty s;
#
# Heling mid fl s an worstemy samathy mevad
# ----
# iter 8100, loss: 23.194263
# ----
#  afasepang thee antanr smshit pllicâ€™ tou fhiswer thyeshafe tysafteiviss d toy,
#
#  Nuiat ro,
#
#  kickegl thy sat, wheed Vetliging ho set, hhe urhith aour fern thaseosthre;
#   borldety,
#  Siswenghengais cre
# ----
# iter 8200, loss: 22.945946
# ----
#  edlo, tore bom am imorselfin supaeife seove, dhithemys  thee fntorregt chem on lo summeifer baithsunt In tur ther that mt
#
# â€˜Thes thee fnal thangheis,
#
# Bed wolrpel  her fath anert f mom lond wovo lo
# ----
# iter 8300, loss: 22.401282
# ----
#  Helt caae the the s;
#
# A werd to herm cloveighend abad alo thom:
#
#  Sastheafet weme-bove,
# f toveld torle, Inet Sed and abone flonoh toake woto at an she-.
#
#
#
# M mopenty:w tie  rad lac thach; to thali
# €™
# ----
# iter 8400, loss: 21.824234
# ----
#  d hithe and the s,t
#
# â€™s chie pis wead he love bourhâ€gakt yeteru shous thare,
#
# kN:
# r thath theel  houchi toHthilf câ€™â€™ with kins he
#
#
#  Sauitâ€˜Tony lishe, d
#
#
# B;ld Nais shs, d eit o anthn-ckoun
# ----
# iter 8500, loss: 21.232497
# ----
#   witheus, watee, an wour st thous amartongs safhent,ag atod he ched cathe  hoade-co
#
# Making that t
# â€™an;
#
#
# Hend rise ades:
#
#  Saoughee frelt titi thich thafe and sety Iâ€™ing stan lowenVinins wtor de
# ----
# iter 8600, loss: 20.654273
# ----
#  as themy to ani het  res lo dathon ham,
#
#  Moued a€˜breis, d
#
#  Mouins sis lhâ€™lunt  mem thig the lovâ€™sysevllith the,  kpameghâ€ging wistor  fee flon hyen t d
#
#
#
#  Mos  t thathed thoug lg:â€™s fte h
# ----
# iter 8700, loss: 20.008975
# ----
#   thamerfne, s m mer reg, wirh moo bomere lonely floweee,
# S to ar theed feun hithâ€™, shor the core loverâ€™is the-cini t amyd
#
# He an  ind ty wilt wo ery lirâ€™ s thee maid thon wig thamaiss  wiety,
#
#
# ----
# iter 8800, loss: 19.493013
# ----
#  e,
#
# A Huce an dlin  n antand sred weey,
#
#  Mouclo bnty:
#
# A suchouAn, Vi
#
# â€˜Vouche,
#
# A surret ;
#
#
# d
#
# Maki™g thad on with feith she dored
#
# Aig
#  Ang lin  nt
#
# Making to dle houg shougy shalt y sur to
# ----
# iter 8900, loss: 19.288240
# ----
#  ed tlou kith the fres pre witheny,
#
#  And norn,
#
#  boue  he shethare an
#
# â€˜And te seofe, Ro
#
#  Aitk-câ€™d co oug
#
#  Ro toe s-akis as lthin s id nrkint amad lorit  oore,
#   toore, wim.
#
#  And roed anol
# ----
# iter 9000, loss: 18.895534
# ----
#  ais,
#
#   he liug buinety,  t
#
# M hadit. s sashâ€™d to eâ€™d, such  venthyysamflise himerfet af asmaf,
#
#  Saithot shld,
# â€™d therâ€™s thre,
#
# AAd alin
#   man,
#
#  And rrerfe-fiflins seed rer sas
#
#
#
#  And h
# ----
# iter 9100, loss: 18.428543
# ----
#  yd himer,  t avon lond taen d dalo abowe anto with him.
#
#  Iny horeer,   aaan unto hith uider, samisushond onederesund  t amond houghing to witerst s se, s cr ones ve-ci,n fr lis, him. thy,ld wesur shs
# ----
# iter 9200, loss: 17.875990
# ----
#  Here cone, s m te thbug tey,
#
#  Morn, pis  aterlee facn
#
#
#
#   harfet or thith he faty lipserses thd shoug halt arte ato sedd
#  â€™d to che he thalfe-bokins thmmrn ligif, the fed than  feeepangsnas or
# ----
# iter 9300, loss: 17.309274
# ----
#   krestor, hon li-f thsuith ther the lou titk,
#
#   smer thy me, toâ€-Vings:
#
#
#
# â˜˜˜wi,g herâ€™d the-bow;
#
#  In this thes fad wo  houng anthâ€™en s:
#
#  Sireshhe sherith th t ed ywismed than t â€˜ping thet
# ----
# iter 9400, loss: 16.766293
# ----
#  ngy fomo to wee,
# â€™d thimmphstous sedd edarâ€™ s;
#
# Herâ€™ kit cher Vin,
#
#  I€˜™d yssepang maddlempand smasuit thit ne a
#
# MRouâ€˜Thimurlee wicl hton his phamed flonako
#
# € hiss;
#
# A thed waret e™ t an
# ----
# iter 9500, loss: 16.325939
# ----
#  aim.
#
#
#   horeet,â€™sthcreet this sasflm,
#
#  Raitasu;
#
#
# A t
#
# H almovesuce-lind he,ld, ofe mirm ret ond wimuishon suito hin.
#
#
# IAnd deiflsafe,ys mo
#
#  Andâ€™d thal my:
#
#  Anoneg tree fasthes;
#
#  thaun sh
# ----
# iter 9600, loss: 15.887940
# ----
#   sath timekasserlphid tre tor trent  tor sn;
#
# â€˜ind watherade win, hhum ligi.wenâ€™d to sceins suitor :
#
# A thet rnes or râ€™d, but tonef ti velt to enty;t wial thy lifing ris an ahem seirt to ofet.
#
# ----
# iter 9700, loss: 15.581282
# ----
#  e,
# â€™d the come, yftv moring
#
#   hovepue sumesuie. hat cre feer shld hee, on erelt thie  hed hi wet  h uit the-bow;
#
#  If thou that triet hatern  hous falosellâ
# â€˜Thrith for thy me-fh anthysld thal p
# ----
# iter 9800, loss: 15.337258
# ----
#  ed Vin are
#
# M thiet Iith thed taig theps thoâ€™enfsen hil.  moa:    fet -bon lishemade sre lovely the chmed do thathe win sath and lovely tome-lied himpege,
#
#  Safe,
# â€™d ore.
#
#
#
#  Moseiphssove oreit,
# ----
# iter 9900, loss: 14.933389
# ----
#  . wie sht :
#
#
#  Bule kiss wi ty,
#
#   hounth ane fovâ€™dnds amasndhohthas ald hou-thoun s;
#
# â€˜vo cerlen,
#
# â€˜And yhto thy lifing wither, buthlo, Rore fas Vrounpset, mhalo time wath s thern;
#
#
#  Anthâ€™d
# ----
# iter 10000, loss: 14.482793
# ----
#  eighen his pa an and
# r en anoher she field-bekineks sit,  he-langs;
#
#  â€™d co sureepand ared has th ale love,â€Ad, horet w;
#
#  IVethas thas madet miswin,
#
# â€Ad li s lin,
#
# â€˜The feepll™ hove he th lore
# ----
# iter 10100, loss: 14.021006
# ----
#  Heldâ€™s chife fan tore thou hailo ertâ€˜Nanin, an ure thit .himoo  ho dorgs cr atorgeld the woret ;
#
#  And like bei thy lips wot mo erpsrpsme, d arâre,
#
#   nither, thor thy mipf lit tr that made lovely
# ----
# iter 10200, loss: 13.568745
# ----
#  asufeeg,, wyore, fres shire, sh s lirt cwer fee;
#
#  Sagurt, d lity that theu them nd athou to bou, wored thee floughing
#
# â€˜Thrt thouc falighef  aamind honey seind
#
# â€˜Sins sed thath kess made wht, wha
# ----
# iter 10300, loss: 13.208957
# ----
#   withe chee areil. sustrively the werld have hilt free  he che with ho fimish thencinegwen thbe flon wimfphs on hnriese fld-to s oweigh twy,
#
#  Saith that than aros af wed hedes,
#  dree  he sherpcâ€™
# ----
# iter 10400, loss: 13.120788
# ----
#  aim mad €ring mous wiâ€˜And as,held ced nemat  un cour fn ant
#
# Ma˜Voun,  kint weoughan;
#
# Ten kiks   nalis, taâ€™s,fserer, faMali-f che to thy life.
#
#  e brit eo red ho an lin, heme ait  thes fuilisset
# ----
# iter 10500, loss: 12.863001
# ----
#  unto cold taremasee anto hilt tre womhemy te withe-beguinsto thore withl, torld hith wirtâ€™is thye,
#
#  Saith thad the-bow;
#
#  If thee pr thoree  mohs thd trein, whe aimosem setr thed her fam.
#
#
#  ky;
#
# ----
# iter 10600, loss: 12.565569
# ----
#  eps tht tre t te lolâ€™dnds temafs shaf all weel,
#
# Beses sadd thall tin waee  oad he che thens,
#
#
# te temer, thyss;
#
# bese tovee, hou woud ther pang enthre andd to the the ared thor terent setlee
#
# ----
# iter 10700, loss: 12.429373
# ----
#  ad Varne wield che pamake lond Ving pold,
#   thile-bo this fn ht pemasmstrith wherf tore and rove,â€™d tabalins nsuse fon fake wnoud y ming himerpen, he lovely teme-b toy lr,o ad tiefwind hrer thath th
# ----
# iter 10800, loss: 12.195890
# ----
#  ave listpssafedeng-hs ravel:
#
# A s to wom ted and werldshous we the saty woore wilt And yoteit, but novevo to arâ€™ seveowa,
#
#
#
# A
#
#  But ortongay sa:
#
#
# A thouseed torlisn wied thee wire thy lipsus love
# ----
# iter 10900, loss: 11.808935
# ----
#  y wieg
#
#  SeolHususend
#
# A thous areithy shded haal. wove-fnc
#
# g barethsurn thef ongand him.
#
#
#
#  And lote thed ans ris am lfas
#
# d all mad bet Vemure that the woreet, thee feud ret not morts arifn,
#
#
# ----
# iter 11000, loss: 11.417428
# ----
#  Herife, t  mue wath te wlolangandcre tore ley s lase tore, shos  wo lishe; i
#
#   herlpasmris thife, shot  maon;
#
# â€˜Ther end lips fat crer than
#
#  Sain erer fn,
# â€˜Thet stem
#
# T te-wo t the-bo s rrer t
# ----
# iter 11100, loss: 11.055696
# ----
#  akisses short a
#
#
#   he tou hyed tiein, h
#
#   harifhses n arhou kick-twerllnd lin,
#
#  Rore thld them than ar shed houghu; hh the lountowe,
#
# d yaderpenfy,
#
# lâ€™sm.d t
#
#  Makiss theed be antoyes she fe
# ----
# iter 11200, loss: 10.707317
# ----
#   lind Vingey lornts shalter s tr therlowis, whtr thor alt dem vertemIfetungascoud pale with with thas thl as, then,  serfesy,
#   ho the le-ciumele-thymsses shed cee faty ther taâ€™, whit the world have
# ----
# iter 11300, loss: 10.375786
# ----
#  thief,
#
# A suith moinf theed
#
# A but susunring to as f eishself,â€™ summ;
#
#
# Tâ€™l.  mooe bein. s tu-fyernthyslips thas nase,  horee s m sas  hoonrh the,  weing mo
#  end hill fned
#
# A thouety,
#  he th rteiw
# ----
# iter 11400, loss: 10.043933
# ----
#  torrent mif sers to ther fnim
#
# B wor med te tad mind
#
# A t maseet cored hitl thdegrnd
#
# A thouety,
#
#  But raoner sht, Iâ€™ll sht, Iâ€™llâ€™d Anty,
#
#
# A thimafssfis thy, f th atort  ker tres theeg,
#
#  And
# ----
# iter 11500, loss: 9.740055
# ----
#  e h to toy shan  laeits tomer,
#
#  Saithem rovely srtfor ted  wat me lifl.
#
#  ce the  liss thye drer ;
#   radele-begniguchernâ€˜Thle-ved thith that thaflo selll fasteru; hh loath lve-bond paan loath thy l
# ----
# iter 11600, loss: 9.432193
# ----
#  ad taâ€™endhenguis crlin, an  r than fome horer shthl with tiee  to the than dond rith wore mait afe foud kiss thdendabind hing seed â€™ seveot Ades  af f an an hous wind as sasfeed,
#
#  Bui, ther s nld
# ----
# iter 11700, loss: 9.151998
# ----
#  .
#
#
#  tout cloy that oree andas win, det  a akd lo the waty walter shsh n y ld
#
# B theaveklphâbob tor all  aaseet aat tore phle,
#
#  Sint Iias thorbety tede ao
#
#  And to thee wothâ€™d tith ast rnd co  hor
# ----
# iter 11800, loss: 8.905098
# ----
#  onefas trem as d to the sed tr and and ty s aned
#
#  king onety to an kre,
#
#  Mored air the wond heu hovaveuy we lovâ€™d,â€˜Ain kit  ore lovâ€™ingsuthâ€™enfaik. wedays tore love-c€™s that and
#  hiwe tye
# ----
# iter 11900, loss: 9.356830
# ----
#  Here poret ywfrter se the wit, ywief wean are;
#
# â€˜Ano  ound ciat t wathepang fon,
#
# âA suthor anowies lied fith thy meis ored amid to thy reHelfee, wiore a dithe and with, watiet secld abad than doveo
# ----
# iter 12000, loss: 9.380668
# ----
#   sur sher floug saim thou wisterle to thy life.
#
#
#
# â€˜Vouch ale,
#
#  Nature thy mrirs;s lin, seighen feichee heis, shoreer than
#
#  S aimishfavoud yikfo  toet move ho de ldore;
#
# A whored hou, t eist
# ----
# iter 12100, loss: 9.202953
# ----
#   ho deploun, bovour, toringand
#
# â€™aos lovely the wores th heed  i
#
#
#  Miaing hoars the beis an urmdhrmusuns d at y me,    the cerles thee wâ€™d to sule lang, ther,
#
#  Rose-chethin twenty:
#
# €˜And yite
# ----
# iter 12200, loss: 8.937159
# ----
#  at lfand wile,
#
#  Sais to to him.
#
#    to alifnlt; himt hiun a palle,  id the comerf lins with ste ald lovely the come and sit, where nevlough ant, d
#
#  And live he laughâ€™d to sigafe-flond hine, shoud
# ----
# iter 12300, loss: 8.664762
# ----
#   that madety,
#
#  Mond lind hean, shan  red worne weepengy t lead te vovâ€™d Anow:
#
#
#  Say wipg twer thee wield then;
#
# â€˜sun, hamt
#
#
#  Beis sainm he the lovowâ€™ wit, bor thy lise ciais than lin,
#  Sind
# ----
# iter 12400, loss: 8.379833
# ----
#  ips with loath that madetl;f the thed hin orâ€™d aain dove lond hing ses we ale horo  mad te the the the the fovely thdrvon;
# A snom.
#
#
#
# A that taer Sares thitâ€™d thas kadith tore wiat him sem anthâ€
# ----
# iter 12500, loss: 8.089332
# ----
#  ad taâ€™en his
#
#   horpelt corn the wit, hoeg,
#
#  Rore ake withe shos eman, het wo-toy wiplphses thy seas massmpret ato thee thou not make withe love frerfe, f trem y sasf tiet y mind
#
# A onty;
#
#
# â€˜The
# ----
# iter 12600, loss: 7.815655
# ----
#  .
#
#
#
# â€˜Thre,  hto thysm,
# r desure thaton,
#
# And thoucherntH veroushld fame his thy ore hilt thee famishe ped he alo tim.
#
#
#  Bnoyeg raderâ€™: s rred han thieg femere,
#
#  Hunting he lovâ€™d, buce thy
# ----
# iter 12700, loss: 7.556131
# ----
#  eing n
#
# â€˜Thanty thougles or en,
# A Anrns wing
#
# A this al râ€™s;
#
#
# A sus
#
#
#
#  Namur sldnd aimints cein,
#
# â€˜And yet nu wore,
#
#  Stain toi imor slthâ€™s shor thaeind he begunty here nev.
#
#  â€™lw:
# ----
# iter 12800, loss: 7.316728
# ----
#  Hat akes  o râ€™d bold flon havo thie lamerââ€™inshclve falthe wieis pa t the lovely come and wilf c mome, doo sove veougwens, the fiel wcorld houc he,  in,
#
#  Mot
# â€™d, and veon knefang sat As d and h
# ----
# iter 12900, loss: 7.102145
# ----
#  akigse. t nd tore
#
#
#  Siaf taâ€™d rithy smad afo, onoy;f kieg homarlothe fieo,â€˜Thou win,
#
#  And lithâ€™d lipl g to tham antareed,
#
#  Mon werss mate a,
#   ho to t make lo-t,â€˜Vouchsenghin t m.
#
#  â€™d â
# ----
# iter 13000, loss: 6.870415
# ----
#   he laughâ€™d to sa ther en hnroug Naid thou-kouikingund beingases pith fresh variety tem Ve ling wathe we phountyâ€˜Bng uithyed Iinie, thou wold thes thed hyere them amid sathe, suot
#
# â€˜Visse; foui
# ----
# iter 13100, loss: 6.653603
# ----
#  alint higlis wasus shafe fom,
#
# Being wint mither sucl mrtsman s thin™an; tos lophous te are timiif s ared wield ties shld-fosr fasisun, poou kidd thor the boree thre,
#
#
#
#  Naderpent hith thourn this f
# ----
# iter 13200, loss: 6.439965
# ----
#   pfare, thou wonder, to alin,
#
# Making them red palafe wored hadirlHs:
#
#
#
# â€˜ks;fdond ur shalt thou know:   r thoung an loo   ad t
#  torg he,  ho  ooned sethef thee, with hirn;
#
# Her, thig thee,
# ----
# iter 13300, loss: 6.261779
# ----
#  ips wo lond do to wie, on areriety h liaf mie  noven, ho the saddlem thy stedl feimery s ave sit, woel with thouf wour tht aty shat th uiksen secred r malie snt, Iâ€™s chae anit am lo ale time aoits t
# ----
# iter 13400, loss: 7.536351
# ----
#  ad tlâ€™d satiet
#
#  Anoning theed, and pins seddirt the with fresh varn;
#   hame and will see sa
#
#
#  Sonrhenghing snthpelt,â€™e samie, thre, red and pale wit, wiel  n the,
#
#
# HSone, shm t
#
#  Bcdes p
# ----
# iter 13500, loss: 8.025810
# ----
#  .o
#    ader fathis thy ld-fan anc
#
# â€˜Thet pating, s
#
#
#
#
# And kuoweed,
#
#  Rote-kins lide with fourenth m eishs thy y the shout  t m   thal and,
#   houc boven;
#
# â€˜And yotred amores ammieis pred amorn
# ----
# iter 13600, loss: 8.164613
# ----
#   de the wilf fot nithe world hath ending miksaf sred hakiss s srrem thas nores  ared him surl an hee, with hthin srmoret lome smet Vesu;wy twin,
#
# â€˜Theg,
#
#
# Mâ€˜Nuth lisser, fain ay,
#
#  And ritl fore t
# ----
# iter 13700, loss: 7.996897
# ----
#  Here to that taâ€™en his sa hon hadold,r che â€™d theer, hiser, toâ€™ahcem tomed thief wieldâ€™s cos hore with wo lovekyAnthe aove dond reed Vonre,
#
# AAeing fith thor fant     te;
#
# BnSangacâ€™lâ€™s wei
# ----
# iter 13800, loss: 7.704396
# ----
#  akisses s o
# Mowe lires am slone, fsthin,
#
# â€˜The c
#
#
# A erlon suchs horer slove leer, end hake withe ano  thes lige core, whe tied faat the world hatheepanikssscr thed ur emy,
#
#  A th uithe set, wherlla
# ----
# iter 13900, loss: 7.396794
# ----
#   lond Vano ,
#
#  Sait  afeing ho lovelâ€™ ud to all
#
# €â€˜But ndwoo an kid,
#
#
# T boteeky s thenty,
#
#  And like a bold-facâ€™d se to tiâ€™en;
#
#
# Bendico lon kre,
#
#  But ratheu  mokis  t etorâ€˜Thou wilt de
# ----
# iter 14000, loss: 7.097703
# ----
#  all ny lo,  ess mit mad torle, wetspho pat
#
#  sut eg to wht rire thee withâ€™s shor thamco thy lipeng move wore tain,
#
# â€˜The lin, win,
#
# â€˜Thrice sath tour famistâ€™d the timond uito hsen,
#
# â€˜Thet p
# ----
# iter 14100, loss: 6.809670
# ----
#   p,
#
#
# A dorefen surl sasfe, e thimping wastor cleit
#
# IT
#
# Beins smaft, t:
#
#   houc  ale teisund hor thamin,
#
#  And ree,  ty lfpfs shld
#
#
#  Anins shoum phself at sted Veaco chern;
#
# Tend lind hengu-t caThou
# ----
# iter 14200, loss: 6.542034
# ----
#  ipsth: s thepwat An hiugntuit shand Vo beed
#
# A thous are;
#
#  Nature thy life.
#
#
#
# â€˜Vouchsand
#
#
# â€˜Swetl widun s amfe, flowern, thom deeld hiui kiged to and
#
# â€˜Thrn;
#
#  Saam.
#
#   hidrns withet sh
# ----
# iter 14300, loss: 6.286422
# ----
#  ad taâ€™ stos fucucA suito werld hous sherte kâ€™d to sus ld-flond palt A on sucâ€™d hour fith teis madd,
#  wornto bovavâ€™begalins thrt,
#  Iâ€™s sald thet lo ant hake woored and yite ar sas  rie,
#
#  But
# ----
# iter 14400, loss: 6.058434
# ----
#  e-begnins wilv,
#
#  Saot lo s th mad
#
#  Sait  tore;
#   cr thre, hing wadd hloweismys rre;
#
# â€˜The four but sathemasetedar Hu and re-bowâ€™d trernthefcer fam.
#
# â€˜And yet not ngest ale tede aoce woald kim
# ----
# iter 14500, loss: 5.833471
# ----
#  yrn;     re losat  fred tourliscemy the coe wovelâ€Sins sad le and tim.
#
#  If thou woll y:
#
#   more theigheee, suitor â€˜gins to at kips with the weas thal fas,
#
#  And liki t amore, hhorâ€™s day wavely t
# ----
# iter 14600, loss: 5.624907
# ----
#  Here Aid weove-bon,
#
#  bure, wore tat aat the world hath eny nhping mores al sure, fait not bon,
#
# Here bove afes samas thle btor shse;
#
#  king ohie ther thee, wied hore wole,
#  co t amo
#  Swasas are;
#
#
# ----
# iter 14700, loss: 5.422004
# ----
#   kisses short as one, one long as fuint, Iâ€™lâ€˜The
#
#
#
# Angyismas mares ld
#
#
# AAdon-com, tâ€™d beiale tore, wâ
#
# â€ndâ€™ s thelbegsas sis,
#
#  And like a bo and veilf thou him prmto lold-€˜gand thepand
# ----
# iter 14800, loss: 5.246221
# ----
#   he lo sh
#
# â€˜Vouchsafe, thou wipland hill venty:
#
#  Sait nd love,â€™: sathepand wilm,
#  S mht to thee hom fon fomrind houc taveating hou seth thor thy mind Venug mose that then anis
#
#  Anonis  rie l
# ----
# iter 14900, loss: 5.299293
# ----
#  and pirt, whclle shld-fastor Ane bovell cimen in sast
#
#
# M kissith s mmerâ€™s ympr
#
#   lovel,
#
# A thimere thiugnthin sus to seas
#
#  Shoug sam pho,  rief hhein.
#
# A st san
#
#  Mored ab˜™mad the-bo s
# ----
# iter 15000, loss: 5.304777
# ----
#   proud tamas thy lip,
#   wmet anign,
#
#  Seith faseprit pase wead hie wâ€™d to salf as thy,
#
#  And heepy ther thet non, thman,
#
# â€˜Ther phlistret, thou won Saas themco, erie with hous onty t dlve rees  a
# ----
# iter 15100, loss: 5.163828
# ----
#  ipf withe we loveeyf,r sand him.
#
#  â€™d co ending with ™ sh wiee thy loathâ€™d satiety,     ied faiels llp,
#
#  Rore kr:ing hime ligh ho lips with loathâ€™d strem aking ftede arer thit dndint yen suchse
# ----
# iter 15200, loss: 4.992955
# ----
#  ad taâ€™ed hite tod sit, sheman,
#
# Besus the lovely thir thoun, d to the stort hou wins ho thonthe wipllr,
#
#
#  But o then,
#
# â€˜The fieldâ€™s che wean,
#
# â€˜The f
#
# â€˜Thre, then sund Vo te aim thin, palee
# ----
# iter 15300, loss: 4.827762
# ----
#  .
#
#   amee thed hisses shidh thd lind
#
# â€˜Thrice fai, thee wich fumplon, themcres res and paouckTen such tyds ais dere;
#
# kâ€˜Vouch toi
# â€™Naos anoris ano ty lon wovell-hsus suthâ€™d to sced y tho
#
# â€
# ----
# iter 15400, loss: 4.667382
# ----
#  rind yecld, thees we t
#
#   Ii sut  tor thoust, that ealint wipigh sher theelpanghte;
#
# Teed, pamumwint hiel f to woor lmo
#   hend ty s am denghiguikn,
#
#
# Beins smas:
#
#
#
# â€˜And y t lounBwath ve thy lifes
# ----
# iter 15500, loss: 4.518576
# ----
#  Here come and sit, where wethe thal theed ageery thee and hou hovely trerâ€™s dayd thse tha
#
# And tire thin dotres;
#
#  Stoyerlinthy thee, thousalf at in kneasce anowdor thit  mat â€˜Vied nas cre thinf
# ----
# iter 15600, loss: 4.374775
# ----
#   kisses the saddlem resdlh-timafself,â€™ thus she began aim seotle womerpend hikith lothy loser thun lo
#
#  Sall wealins Venun  f erses share;
#
# â€˜And y teem afed thoret  hherâ€™e stree famish vo  ho th
# ----
# iter 15700, loss: 4.237093
# ----
#   he la™ghe wath f and and time aovoun cath eilus with ted an, made fafas,
#
#  wothet
#
#
#
#
# Being wasmet and pale with:
#
#  Move wind ty t, Iâ€™lwbed thou know:
#
# Here comere, harm a man,
#
#  More white a
# ----
# iter 15800, loss: 4.110017
# ----
#  time-beguiling ove hind
#
# A thou hat cld to them : m d t
#
#  Monrâ€™ mat mote kises thed ald he the wigl see fakimud loted her en
#
# A shom ther thyeed
#
# AAng th;r find rite bovely cho  tae love, famold ho
# ----
# iter 15900, loss: 3.985827
# ----
#  spwime thee, thad madety thy ld-thand riterle tham am d to the che shld woor thy lipR w:t
# â€˜Vielg thot susm oweeld-veth lond ty long land thee, bitheis,
#
#
# Aâd kety them rsssan,
#
#  Hun no
# â€˜Thdu; Roun
# ----
# iter 16000, loss: 3.875661
# ----
#  ind Vings s n  regho, ent yein,
#
#  Rose-cheekâ€™d Adonis triem limpeit ho safes lip,
#
#  But nd le woo are cored vorse fem derld hike   mastov an on hlis, hime-begnin thee anit ed tree anther fheed tidHt
# ----
# iter 16100, loss: 3.828937
# ----
#  ad taâ€™d tim,
#
#
#
# d line them rei tath t reshondind hikisurlle with frerâ€™akm sed head ree freren, he wit,
#
# â€˜kinknAn hotler lase,
#
#  Stain to thin,
#
# â€˜Thou wind
#
# â€˜Ther fasted in such tor than
# ----
# iter 16200, loss: 3.857885
# ----
#  .
#
#  Ik that thd,
#  Simpsat Asmalo
#  Saompinty falin, mither thed houis tham aros sad th afe t mading hieg uithese;
#
#  Hut ngerârnd hon lin,
#  Sick this thisto afon lips with wild hiug un anc
# mHale thamin,
# ----
# iter 16300, loss: 4.603920
# ----
#  orus she t ro shored wiev, or enphnud bui them rrint yisses;
#
# A thye, shor the core, frelf at If  ros lips withe  sers the, the lo al sath watheed himerasecasare,
#
#  Rose chathe wimathou wim, he shoun,
# ----
# iter 16400, loss: 5.020313
# ----
#  Hand thisels ho shlalin,
#   Bit nd hove,â€™ghoun,
#
#  Rother, Iâ€™lâ€™s
#
# HSty wit an man,
#
#  But ree worndoris m   mo e, wherle, shtrleind dersen,
#
# Adon:
#
# A sus safr thsupt ht the che los lred yid  ad h
# ----
# iter 16500, loss: 5.265564
# ----
#   kisses sho;
#
# â€˜kingsict thy life cre wo lipf ty sammeed,
#
#  suth rips ve liss thouâ€™d thee, them y th ane los theed,
#
#  bus lo
#
# H;
#
# Tendang mired hom hed heicf thinifl,
#
# A suve horee, s m thou won
#
#
# ----
# iter 16600, loss: 5.149691
# ----
#   ferer shstrife flosde and red re-bonef,e tim.
#
#   had t
# Heny with heit, the
#
#
#  â€™d to salf and rimend lbeighegwind pala s sus lg d
#
#   €rede, suth lon,
#
#  Roue ke, thself,â€™ thus she began,
#
# â€˜The
# ----
# iter 16700, loss: 4.969365
# ----
#  alifneglind
#
# A thousty m are;
#
# Se shorer, Iâ€™lon, samashprthleaâ
# Ade aith wond at short,
#
# Being aris thor thy lips with loathâ€™d satiet seabety,
#
#  Sicâ€™s day wild houch ald too ty
#
#
#  wert thoucâ€™
# ----
# iter 16800, loss: 4.774624
# ----
#   ore sand Vongant aad thinty,
#
#
#
#
# y tour thee frethy thsert nessas thinethas ar
#
#
#
#  More wathe thee, with he madit, h alafcedd rtheed uinu  ty loathâ€™e lond hin and he, wirm theed,
#
#  Hunto seave
# ----
# iter 16900, loss: 4.585843
# ----
#  ips with loathâ€™d sall ho tydaties pale,  hou wilt then thy lthe wied tid,
#
#  Rote-cheilf Inthâ€™en his sade, the louis the world hath e and rovelâ€™d bov that then,
#
# â€˜The fieldâ€™s chief,
# r taoo  l
# ----
# iter 17000, loss: 4.401124
# ----
#  ad taâ€™en hisths selllh:
#   res short heed
#
# A thousand honey secretd hhalie sht :
#
#  Sict to the the lovely than thee with kisloves orer lastemur nt r, peighed ho eelhs shld-fakinond withe and red than
# ----
# iter 17100, loss: 4.230020
# ----
#  .
#    al  n anty tham trinAns cim.
#    t red houghseghlis,
#
#  Buce ar salin than a myeigf this favour, for thy m sheel, thee and with wo lovepynt scorernshsun,
#
#  And like a bit, shalt thie lamde,
#
#  But r
# ----
# iter 17200, loss: 4.066474
# ----
#   rhe liug bronet: withe thath to bole tham.
#
#
#
# â€˜Thrn;   alo ato woo himain thanthy ligh lemur thunty sad lo
# l wind the world hathee anskis alm toied wield chouesmonsmrnss fat ther thee with kisses
# ----
# iter 17300, loss: 3.915690
# ----
#  Here come and sit, where wealing vean the sht, dhthin,
#
# â€˜The fieldâ€™s chover fned hersese thre thee, with herself al storn;mas palips tingn suced pareil  m thou wigt
#
# d co that the come and red th
# ----
# iter 17400, loss: 3.770750
# ----
#   kisses;
#
# And being set, Iâ€™ll smother thee with ko ouishome aâ€™disifg,
#   beins samiphsevelflereng niksen;
#  beoun,
#
# â€˜Sweol Ais tre to satielenshshthy mesht,
#
#  Namure;
#
#  HuntHaseafhonth shted made,
# ----
# iter 17500, loss: 3.634869
# ----
#   he lous â€™ind with thy life.    aed Vesuck-lower famish them amid thee wend abo
#
#  And
#
#   om ao a-threld hitl un seceith w ther thyes fathye,
#
#  Saith thy life.
#
#
#
# â€˜Viengy s ther thees, ho nro
# ----
# iter 17600, loss: 3.510416
# ----
#  all n ald have to aliph te to wather thu the lovâ€™d, but lake whet made thee, them red and himerpsond, an lin,
#
#  bute that madem fom fom sethee anowe lam,
#
#  And like a bole,
# â€Adâ€™s ced fem  ale l,
#
# ----
# iter 17700, loss: 3.391070
# ----
#   proud head Ad lou;Slons
#
#
#  â€™d thanca-belenfy,
#
#  And like a bonr th s ad tres lind he lin,
#
#  Hut rathe tiris shem,
#  and hou wit, wheltâ€™d tors anty s aron,
#
# Beo, Sathou wimterle Iâ€™d wove that ma
# ----
# iter 17800, loss: 3.283151
# ----
#  ips with loathâ€™d sand taigâ€™s daot ywor fasfpathy will shem surmerler los thint y s d
#
#
# â€˜Sunting he lovâ€™d, but love he laughâ€™d t ve aseem an hour â€™lo tudare come and red than doves or roses
# ----
# iter 17900, loss: 3.179579
# ----
#  ad taâ€™en his last o,
#
# Here come and sit, where te-bon lins herself tre to peran,
#
# â€˜The fimore lovepengheice saet and Venus fem-soos tlâ€˜Sy l
#
#
# Bed,iThe-co las satiety,
#
#  But rather famish them
# ----
# iter 18000, loss: 3.084557
# ----
#  ein onyswreighyss savelf co e, wield tim.
#
#   him.
#
#  â€™ius suchee, thie that trlon co wit, shalte and sit, wher-fred himery sasfee, t at ther famis, them al€™ wove horer thee freg tr the fee wimlin  n
# ----
# iter 18100, loss: 2.995094
# ----
#  ound thalithy, m t male lovdllang sall ho thy lips with loathâ€™d  amaeed,
#
#  But rather famish the.
#
#
#
# â€˜s,yd hed and pale with wâ€ydâ€™s chilf hhelafe, thy lips with loathâ€™d satiety,
#
#  But rat
# ----
# iter 18200, loss: 2.915299
# ----
#  Here comeed,
#
#  Moue  nou heign this pn hour but seed abere, weri sede, m
#
#  And like hond lalow: thim.
#
#
#
# â€˜Thrico fhedern sund tiee anonisuth for thy ke,
#  boud ch loathâ€™d stor them an dere,  he s
# ----
# iter 18300, loss: 2.844306
# ----
#   kisses s
#
# M
# bein™s mat sust rithy the lold-fakidingeond beong, swerwe, e
# â€˜Vouthsakâ€™d tore, wher fnpser, ti h
#
#  And like anow;
#
# Ten kisses short as one, one boree fasthif;
#
# â€˜Thend-ce tondred sa
# ----
# iter 18400, loss: 2.785591
# ----
#   aros laâ€™ to the chase;
#
#  Hunting he lovâ€™d, but  oned hemane lo the  r sit, where neve and rererh them y ore, t tho
#
#
#
# Beids lded wim to the chastign this favoue, with hern; s thee famin,
#
#
# Bed
# ----
# iter 18500, loss: 2.718471
# ----
#  all nymphses thed waki k the lidâ€™s,
#
# And loone, thou won Hr,er famis, thie, wâ€™â€™d satiety,  nd po to aim see, rieisherl; hâ€™e d mowe he liughâ€™d timins wipf homerses las thest aseir, thereen, m
# ----
# iter 18600, loss: 2.648463
# ----
#   ped,
#
#  sut Haseer thee with kisses:
#
#
#
# â€˜And yet not cloy thy lips with loathâ€™d stre wither thd hamit, where sesun   aovemy,
#
#  A
#
#  And rein hin,
#
#  boteâ€™d satiety,
#
#  But rather lhe;
#
# Be ui t sas
# ----
# iter 18700, loss: 2.585559
# ----
#  ips wo lo freg  veaserf tain ano sed than doves or roses are;
#
#  Nature-thy lips with loath thy life.
#
#
#
# â€˜Vouchsafe ade, dlo, wored th alind hieses lr mate the thova€id ses:
#
# Here core, wher f
# ----
# iter 18800, loss: 2.523667
# ----
#  ad taâ€™en hiserl him,
#
#   ore went Vino wend hiple com chorâ€™s date,
#
#  Savelint
#
# â€˜d the ho chemure that the world hath ending with kiste;-s thoun,
#
# Making themur cher thasum sam sert hon my
# ----
# iter 18900, loss: 2.470617
# ----
#  .
#
#
#
# â€˜Thrice fairer than mydet And
#  And
#
#  sheld the weild, them reiry,
#
# A suithe cor shtht beed halin s ther thee wrou his proud head to the snd to alt Vees famin,
#
#  And llon ties
#
#  Moue  no en h
# ----
# iter 19000, loss: 2.418455
# ----
#  ed yet palo Sathsel wild flowee, she fali tr thrls wo sherf;s
#
#  Stain the lovâ€™d sastrrte wâ€™d to scorees, wretâ€™d wimfef will Anon ssthirel€nd with that made thee, with heman, he laughâ€™d to sc
# ----
# iter 19100, loss: 2.370941
# ----
#  Here nove-winv hiki s red re al mad,
#
#  And nithre lovely thavolloâ€™d thresh variety;
#
# Ten kisses short as one, unty tried hie  lind healclte bre;
#
#  Natore;
#
#  Huned herl;
#
# Making falt thee fimwind wi
# ----
# iter 19200, loss: 2.322230
# ----
#   kisses st d te thee, with herselt temuind timend, ketand hend cabor fliscothâ€™: shirer thy tholle and see thy thmalt warmer thembred red and pingeres to all nos as she betheile,   ir ther ending mit
# ----
# iter 19300, loss: 2.276457
# ----
#   he laughigs sheind hius ane win, and
#
# A thim.
#
#
#
# â€˜Thrrethee,  tried him ed lemad pale ho tharee wompind houcto los thee hlowee sht, Iâ€™ll smothee anowe lin,
#
#  More whee weald haui€™e covâ€™d note
# ----
# iter 19400, loss: 2.245444
# ----
#  all nymphs, the com hore, she t
#
#  Sato shotery sastpei,  t beint seshelling thee anis thtr thed pale with fresan,
#
# Being the ses sho thase;
#
#  And to the than  lins wither feing seth whelafe,    aee wi
# ----
# iter 19500, loss: 2.215388
# ----
#   thintd s ar sloug
#
#  And like a bot
# Ad sutert holo tim.
#
#  Staig r ored abour shthem amid thou
#
#  Stain oore,  i t
#
# Herifnlguce on s hit
#
#  And ho thee ferer, swerfe,
#
# â€˜The fie therlfnd,
#
# A
# ----
# iter 19600, loss: 2.176094
# ----
#  ips with loathâ€™d satied fim to thave at ne aond nike w thee, tief and werld hath ending with thy life-bow;
#
#   fover sere than than,
#
# â€˜The fieldâ€™s chae thee freg tris lasm lave, fat liping himore
# ----
# iter 19700, loss: 2.140079
# ----
#  ad taâ€™, satwe; hâ
# â€˜Thâ€™enthyslfat madetlyfses parn ldowe herh vaat  don dote;
#
#
# Addrisneve and sit, where tem and pale with fresh mad then thy the che the wedds aris lase lold,
# Ant sam, torrelf t
# ----
# iter 19800, loss: 2.103947
# ----
#  .
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s c
# €™d won int he co all n anty  t
#
#  bried him to the chase;
#
#  Muntind hitheg oighlemâ€™d dayash moreushore hithe anoand pale wi
# ----
# ...
#
#  More white and red than doves or rose
# ----
# iter 493300, loss: 0.024243
# ----
#  rife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe, thou wonder, to alight thy steed,
#
#  And rein his proughom der theu know:
#
# Here come and sho, Iâ€™ll smor e
#
#  Roseith sh
# ----
# iter 493400, loss: 0.024248
# ----
#  Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smother Sand ho will seem an hour but short,
#
# Being wasted in such time-beguiling one koses ane with fresh variety;
#
# Ten kisses sh
# ----
# iter 493500, loss: 0.024232
# ----
#   kisses short as one, one long as twenty:
#
# A summerâ€™s dayeey h lomy,
#
#  More white and reave holdety,
#
#  But rather famish them amid their plenty,
#
#  Sick-thoughted Venus makes amain unto him,
#
#  And
# ----
# iter 493600, loss: 0.024221
# ----
#   he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#  And like a bold-facâ€™d suitor â€˜gins to woo him.
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s ch
# ----
# iter 493700, loss: 0.024211
# ----
#  all nymphs, more lovely than a man,
#
#  More white and red than doves or roses are;
#
#  Nature that made thee, with herself at strife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe
# ----
# iter 493800, loss: 0.024213
# ----
#   proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy meed
#
# A thousand honey secrets shalt thou know:
#
# Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smoth
# ----
# iter 493900, loss: 0.024199
# ----
#  ips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
#
# Making them red and pale with fresh variety;
#
# Ten kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an ho
# ----
# iter 494000, loss: 0.024188
# ----
#  ad taâ€™en his last leave of the weeping morn,
#
#  Rose-cheekâ€™d Adonis tried him to the chase;
#
#  Hunting he lovâ€™d, but love he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#
# ----
# iter 494100, loss: 0.024203
# ----
#  .
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s chief flower, sweet above compare,
#
#  Stain to all nymphs, hores fakith aney smcrets shalt thou know:
#
# Here come and ri
# ----
# iter 494200, loss: 0.024182
# ----
#  rife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe, thou wonder, to alight thy steed,
#
#  And rein his proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy me
# ----
# iter 494300, loss: 0.024188
# ----
#  Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smother thee with kisses:
#
#
#
# â€˜And yet not cloy thy lips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
#
# ----
# iter 494400, loss: 0.024172
# ----
#   kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an hour buthsand honey secrets shalt thou know:
#
# Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smother
# ----
# iter 494500, loss: 0.024160
# ----
#   he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#  And like a bold-facâ€™d suitor â€˜gins to woo him.
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s ch
# ----
# iter 494600, loss: 0.024150
# ----
#  all nymphs, more lovely than a man,
#
#  More white and red than doves or roses are;
#
#  Nature that made thee, with herself at strife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe
# ----
# iter 494700, loss: 0.024152
# ----
#   pred than a man,
#
#  More white and red than doves or roses are;
#
#  Nature that made thee, feed
#
# A thousand honey secrets shalt thou know:
#
# Here come and sit, where never serpent hisses;
#
# And being s
# ----
# iter 494800, loss: 0.024138
# ----
#  ips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
#
# Making them red and pale with fresh variety;
#
# Ten kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an ho
# ----
# iter 494900, loss: 0.024127
# ----
#  ad taâ€™en his last leave of the weeping morn,
#
#  Rose-cheekâ€™d Adonis tried him to the chase;
#
#  Hunting he lovâ€™d, but love he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#
# ----
# iter 495000, loss: 0.024143
# ----
#  .
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s chief flower, sweet above compare,
#
#  Stain to all nymphs, more lovely than a man,
#
#  More white and red than doves or rose
# ----
# iter 495100, loss: 0.024122
# ----
#  rife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe, thou wonder, to alight thy steed,
#
#  And rein his proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy me
# ----
# iter 495200, loss: 0.024127
# ----
#  Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smother thee with kisses:
#
#
#
# â€˜And yet not cloy thy lips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
#
# ----
# iter 495300, loss: 0.024111
# ----
#   kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an hour but short,
#
# Being wasted in such time-beguiling one-cheifand ad tathee, with herself at strife,
#
#  Saith that the world hat
# ----
# iter 495400, loss: 0.024100
# ----
#   he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#  And like a bold-facâ€™d suitor â€˜gins to woo him.
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s ch
# ----
# iter 495500, loss: 0.024090
# ----
#  all nymphs, more lovely than a man,
#
#  More white and red than doves or roses are;
#
#  Nature that made thee, with herself at strife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe
# ----
# iter 495600, loss: 0.024092
# ----
#   proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy meed
#
# A thousand honey secrets shalt thou know:
#
# Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smoth
# ----
# iter 495700, loss: 0.024078
# ----
#  ips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
#
# Making them red and pale with fresh variety;
#
# Ten kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an ho
# ----
# iter 495800, loss: 0.024067
# ----
#  ad taâ€™en his last leave of the weeping morn,
#
#  Rose-cheekâ€™d Adonis tried him to the chase;
#
#  Hunting he lovâ€™d, but love he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#
# ----
# iter 495900, loss: 0.024083
# ----
#  .
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s chief flower, sweet above compare,
#
#  Stain to all nymphs, more lovely than a man,
#
#  More white and red than doves or rose
# ----
# iter 496000, loss: 0.024062
# ----
#  rife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe, thou wonder, to alight thy steed,
#
#  And rein his prough mhe weeghlifnts shem strith shtr that them amid their plenty,
#
# M
# ----
# iter 496100, loss: 0.024067
# ----
#  Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smother thee with kisses:
#
#
#
# â€˜And yet not cloy thy lips with loathâ€™d satiety,
#
#  But rather famish them amid than her pnd hies
# ----
# iter 496200, loss: 0.024051
# ----
#   kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an hour but short,
#
# Being wasted in such time-beguiling one pan weale boldends suito hin withou tom inos  to all n anty
#
#
#
#  Natur
# ----
# iter 496300, loss: 0.024040
# ----
#   he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#  And like a bold-facâ€™d suitor â€˜gins to woo him.
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s ch
# ----
# iter 496400, loss: 0.024030
# ----
#  all nymphs, more lovely than a man,
#
#  More white and red than doves or roses are;
#
#  Nature that made thee, with herself at strife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe
# ----
# iter 496500, loss: 0.024032
# ----
#   proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy meed
#
# A thousand honey secrets shalt thou know:
#
# Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smoth
# ----
# iter 496600, loss: 0.024018
# ----
#  ips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
#
# Making them red and pale with fresh variety;
#
# Ten kisses short as one, one lips with loathâ€™d satiety,
#
#  But rather famish
# ----
# iter 496700, loss: 0.024008
# ----
#  ad taâ€™en his last leave of the weeping morn,
#
#  Rose-cheekâ€™d Adonis tried him to the chase;
#
#  Hunting he lovâ€™d, but love he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#
# ----
# iter 496800, loss: 0.024023
# ----
#  .
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s chief flower, sweet above compare,
#
#  Stain to all nymphs, more lovely than a man,
#
#  More white and red than doves or rose
# ----
# iter 496900, loss: 0.024002
# ----
#  rife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe, thou wonder, to alight thy steed,
#
#  And rein his proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy me
# ----
# iter 497000, loss: 0.024008
# ----
#  Here come and sit, where never serpent hisses;
#
# And bein. set, Ifety
# wâ€™d hather thee with kisses:
#
#
#
# â€˜And yet not cloy thy lips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
# ----
# iter 497100, loss: 0.023992
# ----
#   kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an hour but short,
#
# Being wasted in such time-beguiling one an kntaâ€™d to align nes or erough mores  ho alan lasee that   tous ar
# ----
# iter 497200, loss: 0.023981
# ----
#   he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#  Andoâ€™s steis at  loudedeys wipi hs share;
#
# â€˜The fieldâ€™s chief flower, sweet above compare,
#
#  Stain to all nymphs
# ----
# iter 497300, loss: 0.023971
# ----
#  all nymphs, more lovely than a man,
#
#  More white and red than doves or roses are;
#
#  Nature that made thee, with herself at strife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe
# ----
# iter 497400, loss: 0.023973
# ----
#   proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy meed
#
# A thousand honey secrets shalt thou know:
#
# Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smoth
# ----
# iter 497500, loss: 0.023959
# ----
#  ips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
#
# Making them red and rim.
#
#  beddlins with loathâ€™d satie
#  And rie
#   hou wâe  ome hint
#
# â€˜Thrice fairer than myself,â€™ th
# ----
# iter 497600, loss: 0.023948
# ----
#  ad taâ€™en his last leave of the weeping morn,
#
#  Rose-cheekâ€™d Adonis tried him to the chase;
#
#  Hunting he lovâ€™d, but love he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#
# ----
# iter 497700, loss: 0.023964
# ----
#  .
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s chief flower, sweet above compare,
#
#  Stain to all nymphs, more lovely than a man,
#
#  More white and red than doves or rose
# ----
# iter 497800, loss: 0.023943
# ----
#  rife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe, thou wonder, to alight thy steed,
#
#  And rein his proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy me
# ----
# iter 497900, loss: 0.023949
# ----
#  Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smother thee with kisses:
#
#
#
# â€˜And yet not cloy thy lips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
#
# ----
# iter 498000, loss: 0.023933
# ----
#   kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an hour but short,
#
# Being wasted in such time-beguiling one lond
#  besas lheis at ther the saddle-bow;
#
#  If thoun hat made thee int
# ----
# iter 498100, loss: 0.023922
# ----
#   he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#  And like a bold-facâ€™d suitor â€˜gins to woo him.
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s ch
# ----
# iter 498200, loss: 0.023912
# ----
#  all nymphs, more lovely than a man,
#
#  More white and red than doves or roses are;
#
#  Nature that made thee, with herself at strife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe
# ----
# iter 498300, loss: 0.023914
# ----
#   proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy meed
#
# A thousand honey secrets shalt thou know:
#
# Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smoth
# ----
# iter 498400, loss: 0.023900
# ----
#  ips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
#
# Making them red and pale with fresh variety;
#
# Ten kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an ho
# ----
# iter 498500, loss: 0.023890
# ----
#  ad taâ€™en his last leave of the weeping morn,
#
#  Rose-cheekâ€™d Adonis tried him to the chase;
#
#  Hunting he lovâ€™d, but love he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#
# ----
# iter 498600, loss: 0.023905
# ----
#  .
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s chief flower, sweet above compare,
#
#  Stain to all nymphs, more lovely than a man,
#
#  More white and red than doves or rose
# ----
# iter 498700, loss: 0.023884
# ----
#  rife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe, thou wonder, to alight thy steed,
#
#  And rein his proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy me
# ----
# iter 498800, loss: 0.023890
# ----
#  Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smother thee with kisses:
#
#
#
# â€˜And yet not cloy thy lips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
#
# ----
# iter 498900, loss: 0.023874
# ----
#   kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an hour but short,
#
# Being wasted in such time-beguiling one lomed amid their plenty,
#
# Making them red and pale with fresh varie
# ----
# iter 499000, loss: 0.023863
# ----
#   he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#  And like a bold-facâ€™d suitor â€˜gins to woo him.
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s ch
# ----
# iter 499100, loss: 0.023853
# ----
#  all nymphs, more lovely than a man,
#
#  More white and red than doves or roses are;
#
#  Nature that made thee, with herself at strife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe
# ----
# iter 499200, loss: 0.023856
# ----
#   proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy meed
#
# A thousand honey secrets shalt thou know:
#
# Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smoth
# ----
# iter 499300, loss: 0.023842
# ----
#  ips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
#
# Making them red and pale with fresh variety;
#
# Ten kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an ho
# ----
# iter 499400, loss: 0.023831
# ----
#  ad taâ€™en his last leave of the weeping morn,
#
#  Rose-cheekâ€™d Adonis tried him to the chase;
#
#  Hunting he lovâ€™d, but love he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#
# ----
# iter 499500, loss: 0.023847
# ----
#  .
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s chief flower, sweet above compare,
#
#  Stain to all nymphs, more lovely than a man,
#
#  More white and red than doves or rose
# ----
# iter 499600, loss: 0.023826
# ----
#  rife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe, thou wonder, to alight thy steed,
#
#  And rein his proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy me
# ----
# iter 499700, loss: 0.023832
# ----
#  Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smother thee with kisses:
#
#
#
# â€˜And yet not cloy thy lips with loathâ€™d satiety,
#
#  But rather famish them amid their plenty,
#
# ----
# iter 499800, loss: 0.023816
# ----
#   kisses short as one, one long as twenty:
#
# A summerâ€™s day will seem an hour but short,
#
# Being wasted in such time-beguiling one an kntaâ€™en his last leaveos stort as one, one long as twenty:
#
# A sum
# ----
# iter 499900, loss: 0.023805

# %%
# Generate text using the trained model
generated_text = sample(hprev,inputs[0],1000)
text_to_print = ''.join(ix_to_char[ix] for ix in generated_text)
print('Generated Text:\n', text_to_print)
# Out:
# Generated Text:
#
# ind therâ€As, swon
#
#  Mose-cheekâ€™d Adonis tried him to the chase;
#
#  Hunting he lovâ€™d, but love he laughâ€™d to scorn;
#
#  Sick-thoughted Venus makes amain unto him,
#
#  And like a bold-facâ€™d suitor â€˜gins to woo him.
#
#
#
# â€˜Thrice fairer than myself,â€™ thus she began,
#
# â€˜The fieldâ€™s chief flower, sweet above compare,
#
#  Stain to all nymphs, more lovely than a man,
#
#  More white and red than doves or roses are;
#
#  Nature that made thee, with herself at strife,
#
#  Saith that the world hath ending with thy life.
#
#
#
# â€˜Vouchsafe, thou wonder, to alight thy steed,
#
#  And rein his proud head to the saddle-bow;
#
#  If thou wilt deign this favour, for thy meed
#
# A thousand honey secrets shalt thou know:
#
# Here come and sit, where never serpent hisses;
#
# And being set, Iâ€™ll smother thee with kisses:
#
#
#
# â€˜And yet not cloy thy lips with loathâ€™d satiety,
#
#  Ant noo wial theed am.d
#
#
# â€˜Thmut come ad he lovely than a man,
#
#  More white and red than doves or roses are;
#
#  Nature
